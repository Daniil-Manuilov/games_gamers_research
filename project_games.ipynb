# %% [markdown]
# # Проект "Стримчик"

# %% [markdown]
# # Задачи проекта:
#
# 1. **Выявить определяющие успешность игры закономерности**.
#
#
# 2. **Спрогнозировать потенциальную популярность продуктов для планирования рекламных кампаний**.

# %% [markdown]
# # Этапы проекта:
# <a id='top'></a>
#
#
# 1. **[Выгрузка данных](#datas)**
#
#
# 2. **[Изучение данных](#datas_info)**.
#
#      [Выводы](#datas_info_2)
#
#
# 3. **Предобработка данных**:
#
#     [Блок предобработки](#preprocessing)
#     - замена названий столбцов (приведение оных к нижнему регистру);
#     - преобразование типов данных;
#     - выявление пропусков и их замена или удаление.
#
#
# 4. **Исследовательский [анализ](#ex_anal)**:
#
#     - [Сколько игр](#periods) выпускалось в разные годы? Важны ли данные за все периоды?
#     - [Как менялись](#platform) продажи по платформам? За какой характерный срок появляются новые и исчезают старые платформы?
#         И первый [вывод из этого](#vivod_1).
#     - [Изучение данных](#15_16) за соответствующий актуальный период для построения прогноза на 2017 год.
#     - Какие платформы лидируют по продажам, растут или падают? Выбор нескольких потенциально прибыльных [платформ](#vivod_2)
#     - График [«ящик с усами»](#diagramma_top) по глобальным продажам игр в разбивке по платформам. Описание [результата](#vivod_3).
#     - [Изучение](#corr) влияния на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построение диаграммы рассеяния и расчёт корреляции между отзывами и продажами. [Выводы](#vivod_4).
#     - [Соотношение](#other_platforms) выводов с продажами игр на других платформах.
#     - Изучение [общего распределения](#genre) игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с [высокими и низкими](#genres_resume) продажами?
#
#
# 5. **Составление [портрета](#portrait) пользователя каждого региона  (NA, EU, JP)**:
#
#     - Самые популярные платформы ([топ-5](#top_reg)). Различия в долях продаж.
#     - Самые популярные жанры ([топ-5](#genres_top)). Изучение разницы.
#     - Влияет ли рейтинг [ESRB](#esrb) на продажи в отдельном регионе?
#
#
# 6. **Проверка [гипотез](#hyp)**:
#
#     - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#     - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
#
# 7. **[Итоги исследования](#resume) и [общий вывод](#final_resume)**

# %% [markdown]
# # Описание данных
#
# <a id='part1'></a>
#
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# <details>
#   <summary>Рейтинг (нажми меня).</summary>
#
# **Действующие**
#
# **EC** («Early Childhood»)
# «EC» («Early childhood») — «Для детей младшего возраста»: Игра подходит для детей от 3 лет и старше и не содержит материалов, которые родители могли бы счесть неподходящими. Продукты, получившие данный рейтинг, изначально разрабатываются для детей и обычно представляют собой развивающие игры. Некоторые усложнённые развивающие игры могут иметь рейтинг «Everyone».
# Рейтинг ESRB: E («Everyone»)
#
#
# **«E»** («Everyone») — «Для всех»: Содержание вполне подходит для возрастной категории от 6 лет и старше; такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Первой игрой, которая получила данный рейтинг, стала The Simpsons Cartoon Studio(aнг.), выпущенная в 1996 году.
# Рейтинг ESRB: E10+ («Everyone 10 and older»)
#
#
# **«E10+»** («Everyone 10 and older») — «Для всех старше 10 лет»: Возрастная категория — от 10 лет. Проекты с данным рейтингом могут содержать немного больше мультипликационного или мягкого насилия, или несколько откровенные сцены или минимальное количество крови. Рейтинг был принят ESRB 2 марта 2005 года. Первой игрой, которая получила данный рейтинг, стала Donkey Kong: Jungle Beat.
#
#
# **«T»** («Teen») — «Подросткам»: Игра подходит для лиц от 13 лет и старше. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики.
#
#
# **«M»** («Mature») — «От 17 лет»: Материалы игры не подходят для подростков младше 17 лет. Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории. Некоторые торговые сети не продают игры с таким рейтингом несовершеннолетним без согласия родителей.
#
#
# **«AO»** («Adults Only 18+») — «Только для взрослых»: Содержание игры только для взрослых. Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое, а также сцены с обнажением. В 2006-м году данный рейтинг получили 22 продукта, большинство из которых предназначены для персональных компьютеров под управлением Windows и Apple Macintosh. Рейтинг «Только для взрослых» является предметом многочисленных дискуссий, так как накладывает серьёзные ограничения на продажи игры.
#
#
# **«RP»** («Rating Pending»") — «Рейтинг ожидается»: Продукт был отправлен в ESRB и ожидает присвоения рейтинга. Данный логотип используется только на рекламных презентациях и в демо-версиях игр до официального релиза.
#     </details>

# %%
# Импорт всех библиотек, которые могут потребоваться

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
from scipy import stats as st
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Выгрузка данных
# <a id='datas'></a>

# %%
# Импортируем данные в переменную data и выведем их на экран

try:
    data = pd.read_csv('/datasets/games.csv')
except:
    data = pd.read_csv('games.csv')
    
reserved_data = data.copy(deep=True)
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Замечательно. Сепараторы не нужны, всё сохранено людьми и для людей.

# %%
reserved_data.head(1)
# Out:
#          Name Platform  Year_of_Release   Genre  NA_sales  EU_sales  JP_sales  \
# 0  Wii Sports      Wii           2006.0  Sports     41.36     28.96      3.77
#
#    Other_sales  Critic_Score User_Score Rating
# 0         8.45          76.0          8      E

# %% [markdown]
# ## Изучение данных
# <a id='datas_info'></a>

# %%
# Объём таблицы
data.shape
# Out:
# (16715, 11)

# %%
# Информация о таблице
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# Число пропусков
data.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
# Число явных дублей
data.duplicated().sum()
# Out:
# 0

# %%
# Посмотрим число повторяющихся названий
data.Name.value_counts().head(20)
# Out:
# Need for Speed: Most Wanted                12
# Ratatouille                                 9
# FIFA 14                                     9
# LEGO Marvel Super Heroes                    9
# Madden NFL 07                               9
# Angry Birds Star Wars                       8
# LEGO Harry Potter: Years 5-7                8
# Lego Batman 3: Beyond Gotham                8
# Terraria                                    8
# The LEGO Movie Videogame                    8
# Cars                                        8
# FIFA Soccer 13                              8
# LEGO The Hobbit                             8
# LEGO Star Wars II: The Original Trilogy     8
# FIFA 15                                     8
# Madden NFL 08                               8
# Monopoly                                    8
# LEGO Jurassic World                         8
# Major League Baseball 2K11                  7
# FIFA Soccer 11                              7
# Name: Name, dtype: int64

# %%
data.loc[data['Name'] == 'Need for Speed: Most Wanted']
# Out:
#                               Name Platform  Year_of_Release   Genre  \
# 253    Need for Speed: Most Wanted      PS2           2005.0  Racing
# 523    Need for Speed: Most Wanted      PS3           2012.0  Racing
# 1190   Need for Speed: Most Wanted     X360           2012.0  Racing
# 1591   Need for Speed: Most Wanted     X360           2005.0  Racing
# 1998   Need for Speed: Most Wanted       XB           2005.0  Racing
# 2048   Need for Speed: Most Wanted      PSV           2012.0  Racing
# 3581   Need for Speed: Most Wanted       GC           2005.0  Racing
# 5972   Need for Speed: Most Wanted       PC           2005.0  Racing
# 6273   Need for Speed: Most Wanted     WiiU           2013.0  Racing
# 6410   Need for Speed: Most Wanted       DS           2005.0  Racing
# 6473   Need for Speed: Most Wanted      GBA           2005.0  Racing
# 11715  Need for Speed: Most Wanted       PC           2012.0  Racing
#
# ...

# %% [markdown]
# Явных дублей нет. Поскольку в задании не указано, что нужно их найти и обезвредить, считаю, что дублей нет. Как видно выше, **Need for Speed: Most Wanted** есть два релиза на Х360 и ПК. Оба в разные годы: 2005 и 2012. Вики подтверждает, что это разные релизы и нельзя считать из единым.

# %%
data.loc[data['Critic_Score'].isna()].tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16711               LMA Manager 2007     X360           2006.0      Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16713               Spirits & Spells      GBA           2003.0    Platform
# 16714            Winning Post 8 2016      PSV           2016.0  Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 16710      0.00      0.00      0.01          0.0           NaN        NaN
# 16711      0.00      0.01      0.00          0.0           NaN        NaN
# 16712      0.00      0.00      0.01          0.0           NaN        NaN
# 16713      0.01      0.00      0.00          0.0           NaN        NaN
# 16714      0.00      0.00      0.01          0.0           NaN        NaN
#
#       Rating
# 16710    NaN
# 16711    NaN
# 16712    NaN
# ...

# %%
# Посмотрим на уники по платформам, годам, жанрам, всем трём рейтингам.
print('Уники платформ:', data['Platform'].unique())
print()
print('Уники лет:', data['Year_of_Release'].unique())
print()
print('Уники жанров:', data['Genre'].unique())
print()
print('Уники критиков:', data['Critic_Score'].unique())
print()
print('Уники юзеров:', data['User_Score'].unique())
print()
print('Уники возраста:', data['Rating'].unique())
# Out:
# Уники платформ: ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
#
# Уники лет: [2006. 1985. 2008. 2009. 1996. 1989. 1984. 2005. 1999. 2007. 2010. 2013.
#  2004. 1990. 1988. 2002. 2001. 2011. 1998. 2015. 2012. 2014. 1992. 1997.
#  1993. 1994. 1982. 2016. 2003. 1986. 2000.   nan 1995. 1991. 1981. 1987.
#  1980. 1983.]
#
# Уники жанров: ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy' nan]
#
# Уники критиков: [76. nan 82. 80. 89. 58. 87. 91. 61. 97. 95. 77. 88. 83. 94. 93. 85. 86.
#  98. 96. 90. 84. 73. 74. 78. 92. 71. 72. 68. 62. 49. 67. 81. 66. 56. 79.
#  70. 59. 64. 75. 60. 63. 69. 50. 25. 42. 44. 55. 48. 57. 29. 47. 65. 54.
#  20. 53. 37. 38. 33. 52. 30. 32. 43. 45. 51. 40. 46. 39. 34. 35. 41. 36.
#  28. 31. 27. 26. 19. 23. 24. 21. 17. 22. 13.]
#
# ...

# %%
# По длине списка уников названий игр можно сделать вывод о числе игр
len(data['Name'].unique())
# Out:
# 11560

# %% [markdown]
# У нас 11425 игр.

# %% [markdown]
# ### Первые выводы о данных
#
# <a id='1_resume'></a>

# %% [markdown]
# 1. У нас есть **16715 строк и 11 колонок**
# <a id='datas_info_2'></a>
#
#
# 2. **Типы данных** `object`, `float64`. На первый взгляд под замену типы года релиза `Year_of_Release` на `int`, а также `User_Score` на `int`. По какой-то причине он идёт, как `object`.
#
#
# 3. **Пропуски**:
#     - Name                  2
#     - Platform              0
#     - Year_of_Release     269
#     - Genre                 2
#     - NA_sales              0
#     - EU_sales              0
#     - JP_sales              0
#     - Other_sales           0
#     - Critic_Score       8578
#     - User_Score         6701
#     - Rating             6766
#
#
# 4. **Дубликаты**. Нет ни одного явного дубликата. Возможно, есть неявные. Часть игр выходила на разных платформах и, возможно, имела переиздания. Например, Need for Speed: Most Wanted встречается 12 раз. Нужно попробовать выявить здесь неявные дубликаты.
#
#
# 5. **Пропуски**. Сразу на удаление пропуски в названии игры и жанре. Их два. Или по два. Пропуски в годе выхода игры. На удаление сразу. Нам нужны эти данные, заменить их нечем. Как вариант, можно стажёра попросить найти инфу по играм без года, но тут встаёт вопрос: какой год указан? Релиза игры в принципе или её локализации в РФ? Отличаются они или нет? Это чуть более 1% и вряд ли сыграет большую роль.
#
#     Есть пропуски в возрастном цензе, а также рейтингах игроков и критиков. Примерно от 51.32 до 40.09 процентов. Это слишком большое количество для удаления. Часть значений в рейтингах имеет значение `tbd`. Будем менять на `nan`, чтобы отработать пропуски. Пока не очень понятно, что с ними делать, поскольку рейтинги ставить через медиану или среднее не самое разумное, а уже возрастные рейтинги тем паче.
#
#
# 6. **Платформы**. Проверка по интернету говорит, что все платформы есть.
#
#     - GB, вероятно, Game Boy.
#     - DS == некоторые приставки от Nintendo.
#     - 2600 == Atari 2600, что не удивительно с учётом уников лет.
#     Перечислять всё смысла нет, но всё в списке есть в игровых платформах. Об этом говорят как сайт [vgtimes](https://vgtimes.ru/games/platforms/), так и поиск [Яндекс](ya.ru).
#
#
# 7. **Годы**. С 1980 по 2016 годы.
#
#
# 8. **Рейтинги**:
#     **Критиков**: от 13 до 98.
#     **Игроков**: от 0 до 9.7. Значит ли ноль, что нет оценок или это именно такой балл, неизвестно. В описании данных ничего об этом нет.
#     **Возраст**: от "Для всех" (E) до "Только для взрослых", которые в основном предназначены для PC. Ещё есть RP, что обозначает, что игра на момент определения возрастного рейтинга находилась на оценке в ESRB.
#
#
# **Другое**. У нас есть устаревшие рейтинги типа K-A, что значит kids to adults. Ныне это E - everyone. Думаю, что стоит заменить, поскольку задача **Влияет ли рейтинг ESRB на продажи в отдельном регионе?** не ставит условием один год, в котором какие-то определённые рейтинги.
#
# Это [ссылка](https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board) на соответствие действующих старым.
#
# Остальное по ходу. Буду дополнять.

# %% [markdown]
# ## Предобработка данных
# <a id='preprocessing'></a>

# %% [markdown]
# ### Переименование столбцов
#
# <a id='rename'></a>
# Приведём все названия к нижнему регистру, а при необходимости и змеиному.

# %%
data.columns = data.columns.str.lower()
data.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# ### Работа с пропусками, удаление данных

# %% [markdown]
# ####  Удаление пропусков в годах, жанрах и названиях
#
# <a id='nans'></a>

# %%
len(data)
# Out:
# 16715

# %%
# Удалим разом пустоты в названиях, годах и жанрах. Хотя последние, думаю, связаны с названиями.
data.dropna(subset = ['name', 'year_of_release', 'genre'], inplace = True)

# %%
len(data)
# Out:
# 16444

# %% [markdown]
# Удалили 271 строку. То есть, можно было потереть только годы релизов. :)
# ПС. Это 1.62% от числа записей.

# %% [markdown]
# #### Работа с оценками игроков и критиков
#
# <a id='tbd'></a>
# **В оценках от пользователей** было значение `tbd`. Его нужно заменить на `nan`. А уже потом обработать пропуски.
#
# Что касается вопроса про `tbd`, то мне тут видится вариант  to be determined, то есть, подлежит уточнению. Однако Интернет штука такая, что я нашёл ещё интересное. На Гитхабе есть [материал](https://github.com/idapython/src/blob/master/tbd.md) о файлах формата .tbd. И это некие заглушки, которые вместо библиотеки содержат сведения о ней. Всё это для перехода между версиями Пайтон и всё такое. В общем, мне почему-то кажется, что гипотезу аш ноль мы не можем отвергнуть - таки to be determined.

# %%
data.loc[data['user_score'] == 'tbd', 'user_score'] = np.nan

# %%
data['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %% [markdown]
# Поскольку заменить пропуски не на что, в идеале их не трогать. Ни средние, ни медианные значения не могут быть актуальными. Может, игру вообще не оценивали. Считаю, что здесь стоит оставить, как есть.

# %% [markdown]
# #### Работа с данными возрастного рейтинга

# %% [markdown]
# Здесь тоже необходимо сначала поменять значения. К-А и ЕС на Е.
#
# <a id='age_rating'></a>

# %%
data.loc[(data['rating'] == 'K-A'), 'rating'] = 'E'

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'AO', 'EC', 'RP'], dtype=object)

# %%
data['rating'].value_counts()
# Out:
# E       3924
# T       2905
# M       1536
# E10+    1393
# EC         8
# RP         1
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# Тип RP не может быть в продаже. Согласно информации из [WikiPedia](https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board), «RP» («Rating Pending») — «Рейтинг ожидается»: Продукт был отправлен в ESRB и ожидает присвоения рейтинга. Данный логотип используется только на рекламных презентациях и в демо-версиях игр до официальной даты выпуска в продажу.
#
# **Удаляю эту запись**

# %%
data = data.loc[data['rating'] != 'RP']

# %%
len(data)
# Out:
# 16443

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'AO', 'EC'], dtype=object)

# %% [markdown]
# Замечательно! Всего удалены 272 строки из 16715. Это лишь 1.63% от общего числа строк.

# %% [markdown]
# # Пропуски в оценках и рейтинге.
#
#
# <a id='nans_2'></a>
# Итак, источники пропусков.
# В названиях и жанре, по всей видимости, ошибка тех, кто вносил данные. Что касается пропусков в рейтингах, то здесь мнение таково: либо рейтинг не был указан при формировании датасета, либо игра не подвергалась оценке в принципе.

# %%
data.loc[(data['year_of_release'] >= 2003) & (data['rating'].isna())]
# Out:
#                                 name platform  year_of_release         genre  \
# 10                        Nintendogs       DS           2005.0    Simulation
# 20     Pokemon Diamond/Pokemon Pearl       DS           2006.0  Role-Playing
# 27       Pokemon Black/Pokemon White       DS           2010.0  Role-Playing
# 31         Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 33               Pokemon X/Pokemon Y      3DS           2013.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
data.loc[(data['year_of_release'] < 2003) & (data['rating'].isna())]
# Out:
#                                      name platform  year_of_release  \
# 1                       Super Mario Bros.      NES           1985.0
# 4                Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                  Tetris       GB           1989.0
# 9                               Duck Hunt      NES           1984.0
# 12            Pokemon Gold/Pokemon Silver       GB           1999.0
# ...                                   ...      ...              ...
# 16624                    Crossroad Crisis       PS           2000.0
# 16666                   Psychic Detective       PS           1995.0
# 16693                   PGA European Tour      N64           2000.0
# 16694                      Carmageddon 64      N64           1999.0
# 16708  Woody Woodpecker in Crazy Castle 5      GBA           2002.0
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# ###  Преобразование типов
#
# <a id='types'></a>

# %%
# Вспомним типы данных в таблице.

data.dtypes
# Out:
# name                object
# platform            object
# year_of_release    float64
# genre               object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# critic_score       float64
# user_score          object
# rating              object
# dtype: object

# %%
data['year_of_release'] = data['year_of_release'].astype(int)
data['user_score'] = data['user_score'].astype(float)
data.dtypes
# Out:
# name                object
# platform            object
# year_of_release      int32
# genre               object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# critic_score       float64
# user_score         float64
# rating              object
# dtype: object

# %% [markdown]
# Замечательно! Типы поменяли. Возьми с полки пирожок, Даня.

# %% [markdown]
# #### Добавим столб по суммарным продажам в наш датафрейм
#
# <a id='sum'></a>

# %%
data['total_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

# %%
data.head(6)
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
# 5                    Tetris       GB             1989        Puzzle     23.20
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN
# ...

# %% [markdown]
# Немного не по теме, и поздновато, но делать стоит именно после предобработки.
#
# <a id='describe'></a>

# %%
# для эксперимента не совсем по теме
df = data.copy()
df.head(2)
# Out:
#                 name platform  year_of_release     genre  na_sales  eu_sales  \
# 0         Wii Sports      Wii             2006    Sports     41.36     28.96
# 1  Super Mario Bros.      NES             1985  Platform     29.08      3.58
#
#    jp_sales  other_sales  critic_score  user_score rating  total_sales
# 0      3.77         8.45          76.0         8.0      E        82.54
# 1      6.81         0.77           NaN         NaN    NaN        40.24

# %%
data.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16443.000000  16443.000000  16443.000000  16443.000000
# mean       2006.485982      0.264028      0.145937      0.078492
# std           5.875598      0.818400      0.506731      0.311109
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score   user_score   total_sales
# count  16443.000000   7982.000000  7462.000000  16443.000000
# mean       0.047596     68.995114     7.126374      0.536054
# std        0.188011     13.920770     1.499542      1.558828
# min        0.000000     13.000000     0.000000      0.000000
# 25%        0.000000     60.000000     6.400000      0.060000
# ...

# %%
# посмотрим на нули
print(
    'Северная Америка:', data.loc[data['na_sales'] == 0]['na_sales'].count(), 
    'Европа:', data.loc[data['eu_sales'] == 0]['eu_sales'].count(),
    'Япония:', data.loc[data['jp_sales'] == 0]['jp_sales'].count(), 
    'Остальные:', data.loc[data['other_sales'] == 0]['other_sales'].count()
)
# Out:
# Северная Америка: 4448 Европа: 5766 Япония: 10299 Остальные: 6492

# %% [markdown]
# Итак, у нас есть средние значения, медианы, а также 1 и 3 квартили. Минимум и максимум.
#
# <a id='2_resume'></a>
#
# **Среднее** число:
#
#     - продаж (млн):
#
#         - в Северной Америке: 0.264028
#         - в Европе: 0.145937
#         - в Японии: 0.078492
#         - по другим странам: 0.047596
#
#     - оценок (баллы):
#
#         - критики: 69 из 100
#         - игроки: 7 из 10
#
# **Минимальное** число:
#
#     - продаж (млн):
#
#         - в Северной Америке: 0
#         - в Европе: 0
#         - в Японии: 0
#         - по другим странам: 0
#
#     - оценок (баллы):
#
#         - критики: 14 из 100
#         - игроки: 1.5 из 10
#
# **Максимальное** число:
#
#     - продаж (млн):
#
#         - в Северной Америке: 41.360000
#         - в Европе: 28.960000
#         - в Японии: 10.220000
#         - по другим странам: 10.570000
#
#     - оценок (баллы):
#
#         - критики: 98 из 100
#         - игроки: 9.7 из 10
#
#
# С чем может быть связан ноль? Скорее всего, отсутствие стататистики. Округление у нас даёт 6 цифр после запятой, то есть до единиц. И даже 1 проданная игра была бы 0.000001. Значит, это что-то другое.
#
#
# Данные по нулям таковы:
#
# - Северная Америка: 4448
# - Европа: 5766
# - Япония: 10299
# - Остальные: 6492
#
#
# Предположу, что здесь есть сочетание храненения информации давних лет, недоступности информации и чисто региональные особенности. Начну с последнего. Здесь меньше всего выделяется Америка, которая является в какой-то степени законодателем в игровой индустрии. Кроме того, есть игры, которые компании делают в принципе для рынков иных стран. Ну и какая-то часть данных может быть как утрачена, так и не предоставлена. Хотя мне тут больше видится второе.
#
#
# **Пока оставляю так, а дальше по комментариям сориентируюсь**. Или по графику

# %% [markdown]
# ## Исследовательский анализ
# <a id='ex_anal'></a>

# %% [markdown]
# ### Проверим количество игр за различные периоды
# <a id='periods'></a>

# %%
agg_func_count = {'year_of_release': ['count', 'nunique', 'size']}

# %% [markdown]
# Если что, `data.groupby(['year_of_release'])['year_of_release'].agg('count')` делает то же самое, да. :)

# %%
games_per_year = data.groupby(['year_of_release']).agg(agg_func_count)
games_per_year.columns = ['count', 'nunique', 'size']

# %%
games_per_year
# Out:
#                  count  nunique  size
# year_of_release
# 1980                 9        1     9
# 1981                46        1    46
# 1982                36        1    36
# 1983                17        1    17
# 1984                14        1    14
# 1985                14        1    14
# 1986                21        1    21
# 1987                16        1    16
# 1988                15        1    15
# 1989                17        1    17
# 1990                16        1    16
# 1991                41        1    41
# 1992                43        1    43
# 1993                60        1    60
# 1994               121        1   121
# 1995               219        1   219
# 1996               263        1   263
# 1997               289        1   289
# 1998               379        1   379
# 1999               338        1   338
# 2000               350        1   350
# 2001               482        1   482
# 2002               829        1   829
# ...

# %% [markdown]
# <a id='game_grafik'></a>

# %%
(
    data
    .pivot_table(index='year_of_release', values='name', aggfunc='count')
    .plot(kind='line', y='name', figsize=(15, 5), 
    ylabel='Количество', xlabel='Год выпуска игры', 
    title='Количество выпущенных игр за различные периоды', legend=False)
);

# Без сетки нравится больше

# %% [markdown]
# <a id='games_minus'></a>
#
# Кратенько: в 1981 и 1982 году был "бум" - 46 и 36 игр, соответственно. Вероятно, на волне развития технологии. Далее число игр снизилось и держится в диапазоне 14-17 с одни выпадом до 21 в 1986 году. С 1991 рост до 41, к 1993 уже 60 игр. Затем резкий скачок до 121 игры в 1994 году, в 1995 уже 219 игр. Скорее всего, связать это можно с несколькими факторами.
#
# Во-первых, развитие как самих технологий и, соответственно, приставок и РС. Во-вторых, именно в те годы был переход с 8-битных игр на 32-битные и даже 64-битные. А это уже другие графика и возможности. Плюс то поколение, которому не было сложно освоиться с техникой, а, значит, и покупать игры.
#
# Далее идёт постепенный небольшой прирост до 2001 года - 482	игры. Резкий скачок почти в два раза, небольшое пададение и снова постепенный рост. Пиковые годы - 2008 (1427 игр) и 2009 (1426 игр). Это огромное число шутеров, RGP и квестов. Рост явно обусловлен более доступными ПК, за счёт удешевления процессоров и прочих комплектующих. Отсюда рост спроса на развлечения. А потом наблюдается спад. Причём довольно значительный: если в 2011 году было выпущено 1135 игр, то в 2012 только 653. Связано ли это с тем, что издатели перешли на более качественный контент, сложный геймплей, сюжет и прочие умные слова геймеров?
#
# Плюс к этому пришли сетевые игры. Как раз в пики. И многие из них до сих пор популярные, получают аддоны, обновления, но не перестают быть актуальными.
#
# *Я перестал гамать в 2011-2012. Это были Far Cry, Колда по сети и изредка NFS. Квесты не беру в расчёт)*
#
# Мне кажется, что я тут сказал не всё, потеряв мысль. Проверить потом.

# %% [markdown]
# К вопросу о важности данных. Они, безусловно, важны, но нам достаточно взять 2015 и 2016 годы, чтобы сделать прогноз.

# %% [markdown]
# ### Изучим изменения продаж по платформам. Далее выберем те, у которых наибольшие суммарные продажи и построим распределение по годам. Изучим характерные сроки появления и исчезновения новых платформ
# <a id='platform'></a>

# %%
top_platform = data.groupby(['platform'])['total_sales'].agg('sum')

# %%
top_platform.sort_values(ascending=False)
# Out:
# platform
# PS2     1233.56
# X360     961.24
# PS3      931.34
# Wii      891.18
# DS       802.78
# PS       727.58
# PS4      314.14
# GBA      312.88
# PSP      289.53
# 3DS      257.81
# PC       255.72
# GB       254.43
# XB       251.57
# NES      251.05
# N64      218.01
# SNES     200.04
# GC       196.73
# XOne     159.32
# 2600      86.48
# WiiU      82.19
# PSV       53.81
# SAT       33.59
# GEN       28.35
# DC        15.95
# SCD        1.86
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: total_sales, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Сумма продаж по годам выведена верно

# %% [markdown]
# Ярчайший лидер - **PS2**. Она стоит в большом отрыве от остальных. Стоит учесть, что она, как и первая версия, были на тот момент феноменом, что и послужило такой популярности. Тем более, что первый действительно достойный конкурент появился только на пике продаж **PS2** (см. график). Остальные лидеры: X360, PS3, Wii, DS, PS.
#
# <a id='platforms_plot_1990'></a>

# %%
(
    data.query('platform in ["PS2", "X360", "PS3", "Wii", "DS", "PS", "PC"] and \
              year_of_release >= 1990')
    .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
    .plot(grid=True, figsize=(15, 7), 
          xlabel='Год', ylabel='Продано, млн копий', 
          title='График распределения продаж игр по платформам и годам')
    

);

# %%
(
    data.query('platform in ["PS4", "XOne", "PS3", "WiiU", "3DS", "PS2", "X360", "Wii", "DS", "PS", "PC"] and \
              year_of_release >= 2010')
    .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
    .plot(grid=True, figsize=(15, 7), 
          xlabel='Год', ylabel='Продано, млн копий', 
          title='График распределения продаж игр по платформам и годам')
    

);

# %% [markdown]
# Я сознательно взял PC (ПК).
# <a id='vivod_1'></a>
# На графике заметны:
#
#
# 1. Качелеобразное движение линии **ПК** (оранжевый). Есть всплеск после 2005 года с пиком на 2011 год, а затем всё вернулось к обычным показателям. Цикл непрерывен.
#
#
# 2. Выход на рынок принципиально нового игрового элемента - приставки **PlayStation** от Sony (зелёный). Основная масса приставок на тот момент: Dendy, Sega, Sega 2, Super Nintendo. Это приставки от 8 до 64 бит. И тут в 1994 году вышла новая приставка с графикой 3D. Пик пришёлся на 1998 год, когда компания завоевала все страны. Спад популярности примерно в 2003 году. **Жизненный цикл 9 лет**.
#
#
# 3. **PlayStation 2** (красная) вышла в 2000 году, уже ближе к концу года она уровне первой версии, к тому моменту сдающей позиции. Пики пришлись на 2002 и 2004 годы. Не очень понятен провал в 2003 году, поскольку на тот момент конкурентов просто не было, а единственная альтернатива тех лет - **3DO** - на 4-м месте с конца. Падение популярности довольно длительное - до 2011 года. Стоит также отметить, что её пика никто не перебил. **Жизненный цикл 11 лет**.
#
#
# 4. **Nintendo DS** (синий) выходит в 2004 году. За год набирает довольно большую популярность. В 2006 году просадка за счёт просто триумфального выхода **Wii** от Nintendo (о ней ниже, п. 6). Плюс в 2005 вышла **Xbox 360** (о ней в п. 5), которая также отжала часть пользователей. В районе 2007 года идёт заметен мощный рывок вверх, а затем и полноценный спад до 2013 года. **Жизненный цикл 9 лет**.
#
#
# 5. **Xbox 360** от Microsoft (сиреневый) вышла в 2005 году. Первый пик в 2008 году, однако не перебила популярность **Nintendo DS** и **Wii**. Второй пик в 2010 году. В это время - наиболее популярная приставка и самые большие продажи игр для неё. Стоит отметить, что **Wii** резко летит в закат, **Nintendo DS** ещё ниже, а почти на уровне с **Xbox 360** стоит **PlayStation 3** (п. 7). И последняя уже на подоходе к пику популярности. К слову, не превысила уровень **Xbox 360**. **Жизненный цикл 11 лет**.
#
#
# 6. **Wii** - приставка от Nintendo. Стартовала в 2006 году просто феноменально, судя по графику. Её начальный уровень был выше, чем небольшое проседание **Nintendo DS**. Связано с гениальным маркетингом. Приставку ждали так, что ещё на этапе предзаказа всё раскупили. Пик пришёлся на 2009 год. Сама приставка занимает второе место после **PS2**. Довольно быстрый спад (как и у всех) до какого-то момента (2013), а потом медленное угасание интереса до 2016 года. **Жизненный цикл 10 лет**.
#
#
# 7. **PlayStation 3** (фиолетовый) стартовала в 2006 и за два года довольно быстро захватила свою часть аудитории, однако рост в 2008 году замедлился. При этом в том же году усилися рост популярности **Wii**, чуть позже, но всё же рядом пошли на падение спроса **Xbox 360** (с первого своего пика) и ускорилось падение популярности **Nintendo DS**. **Жизненный цикл 10 лет**.
#
#
# Возможно, пики 2008 года стоит связать с кризисом. Люди в кризис ищут утешения в развлечениях.
#
# <hr>
#
# С выходом **Nintendo DS** популярность приставок хоть и отличается, но остаётся примерно на одном уровне. За исключением **Wii**. Пики, скорее всего, связаны с выходом некоторых игр, из-за которых многие готовы покупать приставки / консоли. Кроме прочего, нельзя забывать про маркетинг, который может разовыми акциями создать довольно большие продажи. Что стоит за пиками и довольно резкими чертами линий графика, можно узнать, лишь изучив огромный пласт информации за весь исследуемый период.
#
# <hr>
#
# Жизненный цикл приставок и консолей от 9 до 11 лет. Характерной черты для выхода нет. **PlayStation** была первой приставкой и до момента выхода **PlayStation 2** прошло 6 лет. Уже через 4 года вышла **Nintendo DS**, а потом 2005 (одна) и 2006 (две). Можно сказать лишь, что сроки разработки нового продукта сократились. С другой стороны - производители разные. Та же Sony выпустила **PlayStation 3** только через 6 лет после запуска второй.
#
# Второй график показывает сокращение жизненного цикла новых приставок.
#
# Могу предположить, что в среднем процесс разработки, вне зависимости от начала, занимает примерно 5 лет от момента выхода актуальной версии. При этом работа над новой консолью начинается задолго до окончания жизненного цикла актульного продукта.

# %% [markdown]
# ### Изучим данные 2015 и 2016 года
#
# <a id='15_16'></a>

# %%
# Отдельная переменная приятнее для обработки. 

data_15_16 = data.query('year_of_release >= 2015')

# %%
data_15_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 31 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1108 non-null   object
#  1   platform         1108 non-null   object
#  2   year_of_release  1108 non-null   int32
#  3   genre            1108 non-null   object
#  4   na_sales         1108 non-null   float64
#  5   eu_sales         1108 non-null   float64
#  6   jp_sales         1108 non-null   float64
#  7   other_sales      1108 non-null   float64
#  8   critic_score     457 non-null    float64
#  9   user_score       559 non-null    float64
#  10  rating           595 non-null    object
#  11  total_sales      1108 non-null   float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 108.2+ KB

# %%
data_15_16
# Out:
#                                 name platform  year_of_release       genre  \
# 31         Call of Duty: Black Ops 3      PS4             2015     Shooter
# 77                           FIFA 16      PS4             2015      Sports
# 87      Star Wars Battlefront (2015)      PS4             2015     Shooter
# 94                           FIFA 17      PS4             2016      Sports
# 99         Call of Duty: Black Ops 3     XOne             2015     Shooter
# ...                              ...      ...              ...         ...
# 16699          The Longest 5 Minutes      PSV             2016      Action
# 16703               Strawberry Nauts      PSV             2016   Adventure
# 16710  Samurai Warriors: Sanada Maru      PS3             2016      Action
# 16712        Haitaka no Psychedelica      PSV             2016   Adventure
# 16714            Winning Post 8 2016      PSV             2016  Simulation
#
# ...

# %%
data_15_16.groupby(['platform'])['total_sales'].agg('sum').sort_values(ascending=False)
# Out:
# platform
# PS4     188.15
# XOne     86.29
# 3DS      42.92
# WiiU     20.95
# PS3      20.42
# PC       13.77
# X360     13.48
# PSV      10.50
# Wii       1.32
# PSP       0.12
# Name: total_sales, dtype: float64

# %%
(
    data.query('platform in ["PS4", "XOne", "3DS", "WiiU", "PS3"] and year_of_release >= 2015')
    .pivot_table(index='platform', values='total_sales', aggfunc='sum')
    .plot(kind='barh', grid=True, figsize=(7, 2), 
          xlabel='Платформа', title='График распределения продаж игр по платформам в 2015-2016 годах'
         )
);

# %%
data_15_16.describe()
# Out:
#        year_of_release     na_sales     eu_sales     jp_sales  other_sales  \
# count      1108.000000  1108.000000  1108.000000  1108.000000  1108.000000
# mean       2015.453069     0.136995     0.133520     0.048195     0.040424
# std           0.498017     0.402121     0.432158     0.167160     0.133290
# min        2015.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2015.000000     0.000000     0.000000     0.000000     0.000000
# 50%        2015.000000     0.010000     0.020000     0.010000     0.000000
# 75%        2016.000000     0.090000     0.090000     0.040000     0.020000
# max        2016.000000     6.030000     6.120000     2.790000     2.380000
#
#        critic_score  user_score  total_sales
# count    457.000000  559.000000  1108.000000
# mean      73.015317    6.649016     0.359134
# std       12.077499    1.623769     0.943111
# min       19.000000    0.200000     0.010000
# 25%       67.000000    5.900000     0.030000
# ...

# %%
(
    data.query('platform in ["PS4", "XOne", "3DS"] and year_of_release == 2016')
    .pivot_table(index='platform', values='total_sales', aggfunc='sum')
    .plot(kind='barh', grid=True, figsize=(7, 2), 
          xlabel='Платформа', title='График распределения продаж игр по платформам в 2016 году'
         )
);

# %%
(
    data.query('year_of_release >= 2015') \
    .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
    .plot(kind='line', grid=True, figsize=(10, 6), 
          xlabel='Год', ylabel='Продано, млн копий', 
          title='График распределения продаж игр по платформам и годам')
)

plt.show()

# %% [markdown]
# <a id='falling'></a>

# %%
# График для всех топов с момента начала продаж
(
    data.query('platform in ["PS4", "XOne", "3DS", "WiiU", "PS3"]')
    .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
    .plot(kind='line', grid=True, figsize=(10, 6), 
          xlabel='Год', ylabel='Продано, млн копий', 
          title='График распределения продаж игр по платформам и годам')
    

);

# %%
# График для всех топов за 2015-2016 годы
(
    data.query('platform in ["PS4", "XOne", "3DS", "WiiU", "PS3"] and year_of_release >= 2015')
    .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
    .plot(kind='line', grid=True, figsize=(10, 6), 
          xlabel='Год', ylabel='Продано, млн копий', 
          title='График распределения продаж игр по платформам и годам')
    

);

# %% [markdown]
# В выбранном периоде (2015 и 2016 годы) - 1108 позиций. Почему я выбрал именно два года? Так будет более заметно, растёт или падает.
#
# <a id='vivod_2'></a>
# Ранее я сделал аналитику по 2016 году, но мне не очень понравилось, как выглядит картина. Собственно, картинка не меняется, если выбрать только 2016 год.
#
# Лидируют PlayStation4 (PS4), Xbox One (XOne), Nintendo 3DS (3DS). PS4 с ярко выраженным отрывом более, чем в 4 раза от Nintendo и более, чем в 2.5 раза от XOne.
#
# Собственно, непотопляемый PC на 6 месте в этом зачёте. Если брать только 2016 год, то уже на 4-м. А вот приставки с 4 и 5 мест ушли вниз, причём число продаж игр для них сократилось в 5 и 6 раз. То есть **WiiU** и **PS3** явные аустайдеры.
#
# Потенциально прибыльными будут Xbox One (XOne), Nintendo 3DS (3DS). Прибыль принесёт PlayStation4 (PS4). Но на последнем графике очевидно довольно прямое падение.
#
# Не стоит забывать, что Xbox One в периоде затухания, а вышла в 2013 году. Потенциально есть шанс на выход новой версии платформы в 2017-2018 годах. *На самом деле так и случилось, Xbox One X была представлена в ноябре 2017 года. Насколько вероятно влияние анонса выхода - вопрос. Часть игроков в России точно не стала бы покупать игры, предпочитая отложить на новую приставку.*
# Nintendo 3DS вышла в 2011 году, уже находится в стадии затухания. Не исключён выход новой консоли. Равно как и с моделями от Nintendo и самой Sony. *История говорит, что всё так и получилось*.
#
# Здесь следует изучить анонсы производителей и издателей, изучить, как соотносились их анонсы с реальностью в предыдущие годы, а на основе уже более полной информации занимать позицию. Периоды затухания несколько уменьшились, а потому новые релизы также могут стать с менее длительными промежутками.
#
#
# **Это очень интересно, что Sony столь явный лидер рынке индустрии игровых консолей. Его было бы интересно изучить. Что это? Маркетинг? Дань первому опыту?**

# %% [markdown]
# ### Диаграммы размаха для топа платформ
#
# <a id='diagramma_top'></a>

# %%
# Диграмма размаха для топовых приставок за все годы их существования
(
    data
        .query('platform in ["PS4", "XOne", "3DS", "WiiU", "PS3"]')
        .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
).boxplot()
plt.show()

# %%
(
    data
        .query('platform in ["PS4", "XOne", "3DS", "WiiU", "PS3"]')
        .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
).describe()
# Out:
# platform        3DS         PS3         PS4       WiiU       XOne
# count      6.000000   11.000000    4.000000   5.000000   4.000000
# mean      42.968333   84.667273   78.535000  16.438000  39.830000
# std       18.278261   54.637565   40.567917   7.068244  20.313977
# min       15.140000    3.600000   25.990000   4.600000  18.960000
# 25%       31.775000   34.360000   58.435000  16.350000  24.352500
# 50%       47.560000  107.360000   84.625000  17.560000  40.110000
# 75%       55.267500  124.725000  104.725000  21.650000  55.587500
# max       63.200000  156.780000  118.900000  22.030000  60.140000

# %% [markdown]
# <a id='vivod_3'></a>
#
# - **PS3**. Лидер. Позиции сдал.
#     Минумум: 3.60, максимум: 156.78. Первый квартиль: 34.36, третий квартиль: 124.73. Среднее: 84.67 слишком сильно отличается от медианного значения - 107.36. Этот вопрос, возможно, стоит изучить отдельно. Возможно, это за счёт начала на довольно низких позициях.
#
#
# - **PS4**.
#     Минумум:25.99, максимум: 118.90. Первый квартиль: 58.43, третий квартиль: 104.72. Среднее: 78.54 довольно-таки отличается от медианы - 84.63.
#
#
# - **3DS**.
#     Минумум: 15.14, максимум: 63.20. Первый квартиль: 31.78, третий квартиль: 55.27. Среднее: 42.97 имеет заметное отличие от медианы - 47.56.
#
#
# - **XOne**.
#     Минумум: 18.96, максимум: 60.14. Первый квартиль: 24.35, третий квартиль: 55.59. Среднее: 39.83 почти не отличается от медианы - 40.11.
#
#
# - **WiiU**.
#     Минумум: 15.14, максимум: 63.20. Первый квартиль: 31.78, третий квартиль: 55.27. Среднее: 42.97 тоже имеет заметное отличие от медианы - 47.56.
#
#
# Стоит учитывать, что все приставки появились в разные годы, а потому информация выше может быть спорной, однако, несмотря на разные годы выхода на рынок, все они находятся либо в почти полном закате, либо на стадии заката. Даже, если взять за основу промежуток с 2013 года, получится, что **PS3** лидирует. Её показатель был бы под 100, хотя у остальных - меньше 60. Это можно заменить на [графике](#falling), который я сделал ранее. Кроме того, нас всё же интересует жизненный цикл, а не его часть.
#
#
# Ниже диаграмма размаха для 2015-2016 годов. Можно сказать, что мало отличаются от описанной. Одно большое отличие - приставка **PS3**. Она из огромной коробки превратилась в коробчонку. Остальные немного сдали, но в целом выглядит просто информацией за меньший период. Это объяснимо в том числе тем, что **PS3** старше на пять лет.
#
#
# Поскольку эти диаграммы не требуются для построения выводов и гипотез, я описал первую, используя в том числе `describe`.

# %%
# Диграмма размаха для топовых приставок за 2015-2016 годы
(
    data
        .query('platform in ["PS4", "XOne", "3DS", "WiiU", "PS3"] and year_of_release >= 2015')
        .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
).boxplot()
plt.show()

# %% [markdown]
# ### Влияние отзывов пользователей и критиков на продажи внутри одной популярной платформы.
#
# <a id='corr'></a>
#
# **Диаграмма рассеяния, рассчёт корреляции между отзывами и продажами. Выводы.**
#
# В зачёт идут две относительно перспективных платформы: "PS4", "XOne". Почему именно они? Покажет график ниже. Остальные уже просто не котируются.
#
#
# Из пяти топовых:
# - 3DS в закате. Можно закупать игры для неё, но вряд ли стоит сливать сюда весь бюджет.
#
# - WiiU - неудачная замена Wii, которая набрала едва ли 25 млн продаж на своём пике.
#
# - PS3 в топе вообще за счёт 2015 года. И по сути уже кончилась. Как выше сказано, в 2016 году на 4-м месте вообще стоит PC.
#
#
# Две оставшиеся:
# - PS4 уходит в закат, но имеет шанс на пик. Хотя шанс на это примерно 1 из 5. Уже писал про потенциальные выходы новых платформ.
#
# - XOne тоже уходит в закат, но пока ещё имеет некоторую актульальность, как и PS4.
#
#
# По заданию вообще одна.

# %%
(
    data.query('year_of_release >= 2005')
    .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
    .plot(grid=True, figsize=(15, 7), 
          xlabel='Год', ylabel='Продано, млн копий', 
          title='График распределения продаж игр по платформам и годам')
    

);

# %% [markdown]
# #### Диаграммы рассеяния
# Выведем все диаграммы циклом. Для этого создадим новую переменную по топовым платформам. Именно по ней и пробежит наш итератор

# %%
# Создаю переменную для топовых платформ
top_data = data.query('platform in ["PS4", "XOne"]')

# %%
top_data.head()
# Out:
#                               name platform  year_of_release    genre  \
# 31       Call of Duty: Black Ops 3      PS4             2015  Shooter
# 42              Grand Theft Auto V      PS4             2014   Action
# 77                         FIFA 16      PS4             2015   Sports
# 87    Star Wars Battlefront (2015)      PS4             2015  Shooter
# 92  Call of Duty: Advanced Warfare      PS4             2014  Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 31      6.03      5.86      0.36         2.38           NaN         NaN
# 42      3.96      6.31      0.38         1.97          97.0         8.3
# 77      1.12      6.12      0.06         1.28          82.0         4.3
# 87      2.99      3.49      0.22         1.28           NaN         NaN
# 92      2.81      3.48      0.14         1.23          83.0         5.7
#
#    rating  total_sales
# 31    NaN        14.63
# 42      M        12.62
# 77      E         8.58
# ...

# %%
# Собственно, сам цикл по топовым платформам, где переменная platform 
# принимает значения из столбца top_data['platform'] и затем
# идёт построение диаграммы для этого среза. Так же переменная
# используется в коде скаттера для указания названия графика

for platform in top_data['platform'].unique():
    (
        data
            .loc[data['platform'] == platform]
            .plot(kind='scatter', x='user_score', y='total_sales', 
                  alpha=0.3, figsize=(10, 5),
                  xlabel="Оценки пользователей", ylabel="Продано, млн копий", title=platform)
    );

# %%
for platform in top_data['platform'].unique():
    (
        data
            .loc[data['platform'] == platform]
            .plot(kind='scatter', x='critic_score', y='total_sales', 
                  alpha=0.3, figsize=(10, 5),
                  xlabel="Оценки критиков", ylabel="Продано, млн копий", title=platform)
    );

# %% [markdown]
# На первый взгляд отзывы влияют на покупки, так  как в районе больших оценок много и покупок.

# %% [markdown]
# #### Теперь к корреляции.

# %% [markdown]
# ##### Общая корреляция

# %%
# Общая корреляция между оценками игроков и продажами
corr_users_sales = data_15_16['user_score'].corr(data_15_16['total_sales'])
corr_users_sales
# Out:
# -0.0019642931122463374

# %%
# Общая корреляция между оценками критиков и продажами
corr_critic_sales = data_15_16['critic_score'].corr(data_15_16['total_sales'])
corr_critic_sales
# Out:
# 0.32552662253933357

# %% [markdown]
# ##### Корреляция по платформам

# %% [markdown]
# **Корреляция между оценками игроков и продажами**

# %% [markdown]
# Создам переменные из среза для каждой платформы.
# Рассчитаю корреляцию.
# Почему не циклом? Тут быстрее копипастом.

# %%
data_PS4 = data_15_16.query('platform == "PS4"')
corr_u_PS4 = data_PS4['user_score'].corr(data_PS4['total_sales'])
corr_u_PS4
# Out:
# -0.0597384571263821

# %%
data_XOne = data_15_16.query('platform == "XOne"')
corr_u_XOne = data_XOne['user_score'].corr(data_XOne['total_sales'])
corr_u_XOne
# Out:
# -0.04146733387366271

# %% [markdown]
# **Корреляция между оценками критиков и продажами**

# %%
data_PS4 = data_15_16.query('platform == "PS4"')
corr_c_PS4 = data_PS4['critic_score'].corr(data_PS4['total_sales'])
corr_c_PS4
# Out:
# 0.39284855551305986

# %%
data_XOne = data_15_16.query('platform == "XOne"')
corr_c_XOne = data_XOne['critic_score'].corr(data_XOne['total_sales'])
corr_c_XOne
# Out:
# 0.43088874582136805

# %%
print('PS4 Корреляция между оценками игроков и продажами:', corr_u_PS4)
print('PS4 Корреляция между оценками критиков и продажами:', corr_c_PS4)
print()
print('XOne Корреляция между оценками игроков и продажами:', corr_u_XOne)
print('XOne Корреляция между оценками критиков и продажами:', corr_c_XOne)
# Out:
# PS4 Корреляция между оценками игроков и продажами: -0.0597384571263821
# PS4 Корреляция между оценками критиков и продажами: 0.39284855551305986
#
# XOne Корреляция между оценками игроков и продажами: -0.04146733387366271
# XOne Корреляция между оценками критиков и продажами: 0.43088874582136805

# %% [markdown]
# По оценкам игроков по двум платформам (**PS4 и XOne**) корреляция явно стремится к нулю (-0.06 и -0.04 сответственно) при этом с отрицательной тенденцией.
# <a id='vivod_4'></a>
# Связь между покупками и оценками критиков тоже имеет достаточно выраженную связь: 0.39 и 0.43 сответственно.
# Отсюда два посторонних и интересных вопроса:
# 1. Почему оценки игроков не влияют на покупки, если по сути они одинаковы с оценками критиков чаще всего?
# 2. Не ставят ли игроки оценки играм, основываясь на уже известных им оценках критиков?

# %% [markdown]
# ### Соотношение с продажами на других платформах
#
# <a id='other_platforms'></a>

# %% [markdown]
# <div class="alert alert-info">Как мне сказали, это немного проблема с русским языком и вообще имели в виду остальные отобранные платформы. И соотнести не продажи, а сделать те же действия, что выше - корреляция и график рассеяния. То, что сделал ранее, не убираю. Пусть висит. Интересная же инфа. Плиз, поменяйте для будущих студней)
#
# По отобранным платформам сделал выше в одном пункте. </div>

# %%
# Посмотрим описание
data.groupby('platform')['total_sales'].describe()
# Out:
#            count      mean       std   min     25%    50%     75%    max
# platform
# 2600       116.0  0.745517  0.956160  0.07  0.3075  0.480  0.7800   7.81
# 3DO          3.0  0.033333  0.023094  0.02  0.0200  0.020  0.0400   0.06
# 3DS        512.0  0.503535  1.441271  0.01  0.0500  0.120  0.3325  14.60
# DC          52.0  0.306731  0.468660  0.02  0.0775  0.135  0.2975   2.41
# DS        2121.0  0.378491  1.436042  0.01  0.0500  0.110  0.2700  29.80
# GB          97.0  2.622990  5.390925  0.06  0.3000  1.180  2.1800  31.38
# GBA        811.0  0.385795  0.899654  0.01  0.0550  0.160  0.3900  15.84
# GC         542.0  0.362970  0.693974  0.01  0.0600  0.150  0.3675   7.06
# GEN         27.0  1.050000  1.490041  0.03  0.0700  0.150  1.7050   6.02
# GG           1.0  0.040000       NaN  0.04  0.0400  0.040  0.0400   0.04
# N64        316.0  0.689905  1.322189  0.01  0.1300  0.270  0.6000  11.90
# NES         98.0  2.561735  5.108012  0.06  1.0000  1.375  2.2225  40.24
# ...

# %%
# Диграмма размаха. 

data.boxplot(column='total_sales', by='platform',figsize=(25,12), grid=False)
plt.show()

# %%
# График, который покажет продажи общего числа игр
(data
    .pivot_table(index='platform', values='total_sales', aggfunc='sum')
    .sort_values(by='total_sales', ascending=True)
    .plot(kind='barh', grid=False, figsize=(20, 10), 
          title=('График распределения продаж игр по платформам'), 
          xlabel='Платформа', 
          ylabel='Продажи, млн шт.'
         )
               
);

# %% [markdown]
# <a id='vivod_5'></a>
#
# Вряд ли можно делать адекватные сравнения для приставок 80-90 годов и суперсовременных платформ. Среди представленных есть и карманные, и стационарные. Некогда в зависимости от платформы игра на одном картридже могла быть как одна (Ninendo, Sega), так и несколько (Dendy). При этом сами игры были совершенно иными. Стоит отметить, что ворастные ограничения начали вводить в 1994 году. Да и то только в США и Канаде. К началу 2003 года рейтинги получили только 8000+ игр, то есть, достаточно небольшая часть. В том же 2003 заработал PEGI, европейский аналог ESRB. Японская ассоциация - CERO - работает с 2002 года. Потому некоторая часть игр покупалась и использовалась детьми, которым после введения ограничений игру не купили бы скорее всего. А это довольно много миллионов копий Mortal Kombat, например. С другой стороны, есть информация, что некоторая часть игр продавалась с возрастным цензом, принятым для кинопроката. То есть какие-то ограничения местами были.
#
#
# Теперь к самим продажам. Размах по популярным приставкам / консолям они **сопоставим**. По основному размаху отличия есть, а вот по выбросам очень похожи: на всех видны большие выбросы. Это мегапопулярные игры. Например, для NES - Super Mario Bros. (40,24 млн экз.) и Super Mario Bros. 3 (17,28 млн экз.); у SNES - 	Super Mario World, 20 млн копий (к 25 июня 2007 г.). А выброс Wii объясняется простейшим образом: игра Wii Sports продавалась вместе с консолью (кроме Японии и Южной Кореи), а потому продали 79,6 млн копий.
#
#
# В то же время общее число проданных игр показывает достаточно большую разницу. О разнице в популярности и сроках писал ранее.
#
#
# По всем платформам создаётся впечатление, что были десятки или сотни игр, которые продавались просто потому, что играть нужно во что-то. И были некие культовые игры, продаваемые многомиллионными тиражами.
#
#
# Вообще, очень интересный график. У всех есть выборосы за верхними границами. И довольно много. Значит ли это, что не так что-то с данными и вообще всё неправильно? Увидим в комментарии ревьюера.

# %%
data_WiiU = data.query('platform == "WiiU"')
corr_u_WiiU = data_WiiU['user_score'].corr(data_WiiU['total_sales'])
corr_c_WiiU = data_WiiU['critic_score'].corr(data_WiiU['total_sales'])

# %%
data_PS3 = data.query('platform == "PS3"')
corr_u_PS3 = data_PS3['user_score'].corr(data_PS3['total_sales'])
corr_c_PS3 = data_PS3['critic_score'].corr(data_PS3['total_sales'])

# %%
data_3DS = data_15_16.query('platform == "3DS"')
corr_u_3DS = data_3DS['user_score'].corr(data_3DS['total_sales'])
corr_c_3DS = data_3DS['critic_score'].corr(data_3DS['total_sales'])

# %%
data_PC = data_15_16.query('platform == "PC"')
corr_u_PC = data_PC['user_score'].corr(data_PC['total_sales'])
corr_c_PC = data_PC['critic_score'].corr(data_PC['total_sales'])

# %%
print('WiiU Корреляция между оценками игроков и продажами:', corr_u_WiiU)
print('WiiU Корреляция между оценками критиков и продажами:', corr_c_WiiU)
print()
print('3DS Корреляция между оценками игроков и продажами:', corr_u_3DS)
print('3DS Корреляция между оценками критиков и продажами:', corr_c_3DS)
print()
print('PS3 Корреляция между оценками игроков и продажами:', corr_u_PS3)
print('PS3 Корреляция между оценками критиков и продажами:', corr_c_PS3)
print()
print('PC Корреляция между оценками игроков и продажами:', corr_u_PC)
print('PC Корреляция между оценками критиков и продажами:', corr_c_PC)
# Out:
# WiiU Корреляция между оценками игроков и продажами: 0.4002190202148617
# WiiU Корреляция между оценками критиков и продажами: 0.34837976012017485
#
# 3DS Корреляция между оценками игроков и продажами: 0.19879627008102982
# 3DS Корреляция между оценками критиков и продажами: 0.17757455046092874
#
# PS3 Корреляция между оценками игроков и продажами: 0.12841562938563025
# PS3 Корреляция между оценками критиков и продажами: 0.4327589578997139
#
# PC Корреляция между оценками игроков и продажами: 0.15038053045029076
# PC Корреляция между оценками критиков и продажами: 0.3773317477241351

# %% [markdown]
# <a id='vivod_6'></a>
#
# Интересная картина. **PS3** в своих корреляциях вполне похожа на **PS4 и XOne**. Хотя у нее по игрокам положительная и всё же измеряется десятыми долями. Это приставки от Sony и Microsoft. А приставки от Nintendo имеют, во-первых, более высокую корреляцию по оценкам игроков, чем критиков, а во-вторых, они достаточно схожи. Это могло бы положить начало новому исследованию по уровням доверия игроков в зависимости от предпочтения брендов.
#
# Собственно, сама кореляция.
#
# **WiiU** заметна связь в обоих случаях (игроки 0.40 и критики 0.35)
#
#
# **3DS** - корреляция совсем не очевидна и стремится ближе к нулю. Но всё же какая-то зависимость есть (игроки 0.2 и критики 0.18).
#
#
# **PS3** - практически нет по оценкам игроков, но средняя зависимость от оценок критиков (игроки 0.13 и критики 0.43).
#
# **PC** - для уверенной связи между оценками игроков и продажами корреляция маловата, но какая-то небольшая есть. Связь между оценками критиков и продажами заметнее.
#
# Ну, и графики ниже.

# %%
top_2_data = data.query('platform in ["3DS", "WiiU", "PS3", "PC"]')

for platform in top_2_data['platform'].unique():
    (
        data
            .loc[data['platform'] == platform]
            .plot(kind='scatter', x='user_score', y='total_sales', 
                  alpha=0.3, figsize=(5, 3),
                  xlabel="Оценки пользователей", ylabel="Продано, млн копий", title=platform)
    );
    (
        data
            .loc[data['platform'] == platform]
            .plot(kind='scatter', x='critic_score', y='total_sales', 
                  alpha=0.3, figsize=(5, 3),
                  xlabel="Оценки критиков", ylabel="Продано, млн копий", title=platform)
    );

# %% [markdown]
# ### Общее распределение по жанрам.
#
# **Самые прибыльные жанры и различия в жанрах по продажам**  <a id='genres'></a>

# %%
# Нарисуем гистограммы для всех лет и выбранного периода (2015 и 2016 годы)
(
    data
    .pivot_table(index='genre', values='total_sales', aggfunc='sum')
    .sort_values(by='total_sales', ascending=True)
    .plot(kind='barh', y='total_sales', figsize=(8, 3), 
    ylabel='Продано, млн копий', xlabel='Жанр',
    title='Количество проданных игр по жанрам', legend=False, grid=True)
);

(
    data
    .query('year_of_release >= 2015')
    .pivot_table(index='genre', values='total_sales', aggfunc='sum')
    .sort_values(by='total_sales', ascending=True)
    .plot(kind='barh', y='total_sales', figsize=(8, 3), 
    ylabel='Продано, млн копий', xlabel='Жанр',
    title='Количество проданных игр по жанрам за 2015-2016 годы', legend=False, grid=True)
);

(
    data
    .query('2000 <= year_of_release <= 2015')
    .pivot_table(index='genre', values='total_sales', aggfunc='sum')
    .sort_values(by='total_sales', ascending=True)
    .plot(kind='barh', y='total_sales', figsize=(8, 3), 
    ylabel='Продано, млн копий', xlabel='Жанр',
    title='Количество проданных игр по жанрам за 2000-2015 годы', legend=False, grid=True)
);

(
    data
    .query('1985 <= year_of_release >= 2000')
    .pivot_table(index='genre', values='total_sales', aggfunc='sum')
    .sort_values(by='total_sales', ascending=True)
    .plot(kind='barh', y='total_sales', figsize=(8, 3), 
    ylabel='Продано, млн копий', xlabel='Жанр',
    title='Количество проданных игр по жанрам за 1985-2015 годы', legend=False, grid=True)
);

# %% [markdown]
# И сделаем линейные графики. Первый по всем годам, второй за период с 2000 года. Поскольку у нас есть чёткие пять лидеров + внезапно ворвавшийся жанр Platform, сделаем графики только по ним. Через список.

# %%
(
    data
    .query("genre in ['Sports', 'Platform', 'Role-Playing', 'Misc', 'Shooter', 'Action']")
    .pivot_table(index='year_of_release', columns='genre', values='total_sales', aggfunc='sum')
    .plot(grid=True, figsize=(15, 7), 
          xlabel='Год', ylabel='Продано, млн копий', 
          title='График распределения продаж игр по жанрам и годам', alpha=0.8)
);

(
    data.query("genre in ['Sports', 'Platform', 'Role-Playing', 'Misc', 'Shooter', 'Action'] and \
    year_of_release >= 2010")
    .pivot_table(index='year_of_release', columns='genre', values='total_sales', aggfunc='sum')
    .plot(grid=True, figsize=(15, 7), 
          xlabel='Год', ylabel='Продано, млн копий', 
          title='График распределения продаж игр по жанрам с 2010 года', alpha=0.8)
);

# %% [markdown]
# **Выводы по жанрам**.
# <a id='genres_resume'></a>
#
# **2015-2016 годы**:
#
#
# - Shooter
# - Action
# - Sports
# - Role-Playing
#
# С огромным отставанием:
# - Misc
#
# Скорее всего, этот жанр даже стоит исключить, оставив только 4 топа.
#
# Шутеры и экшн идут довольно ровно. С большим отрывом идут спорт и ролевые. Но этот открыв не настолько страшен, как позиция Misc.
#
#
# **Всё время**:
#
#
# - Action
# - Sports
# - Shooter
# - Role-Playing
# - Platform
# ---
# В пяти популярных жанрах перемены небольшие. Три жанра поменялись местами, а один жанр выбыл, его место занял новый, став пятым в списке за два года. Впрочем, в общем зачёте он как раз шёл шестым.
#
#
# Перестановки в принципе идут всё время. И Platform вошёл в общий зачёт только за счёт своего солидного возраста, потеснив Misc, возникший в 1991 году.
#
#
# Собственно, первые три места до 2015 года были распределены так:
#
# - Action
# - Sports
# - Shooter
#
# 4 и 5 места делили Misc и Role-Playing. Ролевые, как я понимаю, это RPG, MMORPG и прочее. Так и не узнал, что это за жанр. Судя по классификации 1984 года, это может быть сокращение от Miscellaneous, то есть, не вошедшее в предыдущие жанры. Но так ли это? Аркады, головоломки, квесты и прочее?
#
# ---
#
# Наблюдается заметный рост во всех жанрах за счёт интенсивного развития индустрии, однако Platform идёт в самом низу, а вот Action и Sports растут просто феноменально. Что и не удивительно. В экшн входят игры по мотивам культовых фильмов, спорт сам по себе набирает популярность (особенно футбол, который соккер). Что касается шутеров, они растут куда медленнее. И в последние два года вылезли лишь за счёт спада по двум первым позициям. Плюс развитие серий Far Cry и Call of Duty, у которых миллионы фанатов.
#
#
# На графике за 6 лет (с 2010 по 2016 годы) выраженное падение. Именно тут в первой половине 2015 года шутеры выходят на первый план. Выход Star Wars Battlefront и Fallout 4 вполне могут объяснить, почему падение популярности жанра меньше, чем у остальных. А спорт они обогнали ещё в начале 2010 года.
#
#
# Теперь по самым неприбыльным жанрам. Это их список в разные периоды на разных местах:
#
# - Puzzle
# - Strategy
# - Simulation
# - Adventure
# - Fighting
#
# Кроме 2015-2016 годов. Там вошли **Platform** и **Racing** вместо Adventure и Fighting.
#
#
# Puzzle, Strategy, Adventure не набрали и 250 млн продаж каждый, а Fighting и Simulation - до 500 млн копий.

# %%
data['genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# ## Портрет пользователя по регионам
# <a id='portrait'></a>
# **Задачи**:
# 1) Описать самые популярные платформы (топ-5); различия в долях продаж.
# 2) Найти самые популярные жанры (топ-5). Пояснить разницу, если есть.
# 3) Уточнить, влияет ли рейтинг ESRB на продажи в отдельном регионе.

# %% [markdown]
# ### ТОП-5 популярных платформ на 2015-2016 годы для каждого региона
#
# <a id='top_5_plat'></a>

# %%
NA_top_platform = (data_15_16.groupby('platform')['na_sales'].sum().sort_values(ascending=False).head())
EU_top_platform = (data_15_16.groupby('platform')['eu_sales'].sum().sort_values(ascending=False).head())
JP_top_platform = (data_15_16.groupby('platform')['jp_sales'].sum().sort_values(ascending=False).head())
OT_top_platform = (data_15_16.groupby('platform')['other_sales'].sum().sort_values(ascending=False).head())

print('Северная Америка:', NA_top_platform)
print()
print('Европа:', EU_top_platform)
print()
print('Япония:', JP_top_platform)
print()
print('Остальные:', OT_top_platform)
# Out:
# Северная Америка: platform
# PS4     63.86
# XOne    50.30
# 3DS     10.31
# WiiU     8.86
# X360     8.05
# Name: na_sales, dtype: float64
#
# Европа: platform
# PS4     83.54
# XOne    28.10
# PC       9.10
# 3DS      7.39
# PS3      7.30
# Name: eu_sales, dtype: float64
#
# Япония: platform
# 3DS     23.55
# PS4     12.05
# PSV      8.41
# PS3      4.97
# WiiU     4.12
# Name: jp_sales, dtype: float64
#
# Остальные: platform
# PS4     28.70
# XOne     7.71
# PS3      2.49
# 3DS      1.67
# WiiU     1.48
# Name: other_sales, dtype: float64

# %%
NA_top_platform.plot(x='platform', y='na_sales', kind='bar', figsize=(6,2), 
                     grid=False, title='Топ-5 в Северной Америке', 
                     xlabel="Платформа", ylabel='Число продаж, млн копий');

# %%
EU_top_platform.plot(x='platform', y='eu_sales', kind='bar', figsize=(6,2), 
                     grid=False, title='Топ-5 в Европе',
                     xlabel="Платформа", ylabel='Число продаж, млн копий');

# %%
JP_top_platform.plot(x='platform', y='jp_sales', kind='bar', figsize=(6,2),
                     grid=False, title='Топ-5 в Японии',
                     xlabel="Платформа", ylabel='Число продаж, млн копий');

# %%
OT_top_platform.plot(x='platform', y='others_sales', kind='bar', figsize=(6,2),
                     grid=False, title='Топ-5 в остальных регионах',
                     xlabel="Платформа", ylabel='Число продаж, млн копий');

# %% [markdown]
# <a id='top_5_plat_reg'></a>
# - **Северная Америка**:
#
#    1. **PS4** aka PlayStation 4 от Sony, 63.86 млн.
#    2. **XOne** от Microsoft - 50.30 млн
#    3. **3DS** от Nintendo с 10.31 млн
#    4. **WiiU** от Nintendo и 8.86 млн
#    5. **X360** с 8.05 млн от Microsoft
#
#
# - **Европа**:
#
#    1. **PS4** - 83.54 млн
#    2. **XOne** - 28.10 млн
#    3. **PC** - 9.10 млн
#    4. **3DS** - 7.39 млн
#    5. **PS3**, то есть PlayStation 3 (Sony), 7.30 млн
#
#
# - **Япония**:
#
#    1. **3DS** - 23.55 млн
#    2. **PS4** - 12.05 млн
#    3. **PSV**, известная как PlayStation Vita, 8.41 млн
#    4. **PS3** - 4.97 млн
#    5. **WiiU** - 4.12 млн
#
#
# - **Остальной мир**:
#
#    1. **PS4** - 28.70 млн
#    2. **XOne** - 7.71 млн
#    3. **PS3** - 2.49 млн
#    4. **3DS** - 1.67 млн
#    5. **WiiU** - 1.48
#
# ---
#
# **PS4** лидирует во всём мире, за исключением Японии, где у неё второе место. Столь явное отличие не совсем понятно, так как со второго по четвёртое места стоят изделия фирмы Sony. И только на пятом снова Nintendo с WiiU. Впрочем, в Японии лишь два реальных игрока и рынок по сути поделён примерно 50/50.
#
#
# В **Японии**в ТОП-5 нет американских приставок.
#
#
# В **Северной Америке** рынок делится между изделиями трёх компаний (Sony, Microsoft и Nintendo), причём **XOne** довольно слабо отстаёт от **PS4**.
#
#
# Отличилась **Европа**. В ней в ТОП-5 вошли **ПК** (PC). Их немного, но они занимают третье место после **PS4** и **XOne**.
#
#
# **Остальной мир** делят все три компании. Первым идёт **PS4**, за ней с огромным отставанием в 3.7 раза идёт **XOne**.
#
#
# С чем связано? **PS4** на этот момент самая популярная консоль. Её популярность постепенно снижается в сравнении с прошлыми годами, но всё равно пока это весьма большие числа. Её реальный конкурент - **XOne**. За счёт стоимости вероятно. Поскольку по качеству **3DS** приятнее продукта Microsoft.
#
#
# **PSV** есть только в Японии и это чисто географическая причина. Обычная переносная, карманная консоль. Довольно локальный продукт, который очень популярен в Азии, и абсолютно не зашёл в Европе и Америке.
#
#
# **PC** в Европе занимает 3 место. С довольно большой цифрой. Нельзя исключать, что за счёт России, РБ и Украины, где в регионах достаточно много игроков, которые не могут себе позволить покупки консолей.

# %% [markdown]
# ### ТОП-5 популярных жанров по регионам за 2015-2016 годы
#
# <a id='top_5_genre'></a>

# %%
NA_top_genre = data_15_16.groupby('genre')['na_sales'].sum().sort_values(ascending=False).head()
EU_top_genre = data_15_16.groupby('genre')['eu_sales'].sum().sort_values(ascending=False).head()
JP_top_genre = data_15_16.groupby('genre')['jp_sales'].sum().sort_values(ascending=False).head()
OT_top_genre = data_15_16.groupby('genre')['other_sales'].sum().sort_values(ascending=False).head()

print('Северная Америка:', NA_top_genre)
print()
print('Европа:', EU_top_genre)
print()
print('Япония:', JP_top_genre)
print()
print('Остальные:', OT_top_genre)
# Out:
# Северная Америка: genre
# Shooter         48.18
# Action          33.68
# Sports          26.31
# Role-Playing    19.82
# Misc             5.58
# Name: na_sales, dtype: float64
#
# Европа: genre
# Shooter         40.28
# Action          34.82
# Sports          27.82
# Role-Playing    17.21
# Racing           6.52
# Name: eu_sales, dtype: float64
#
# Япония: genre
# Action          23.05
# Role-Playing    13.41
# Shooter          3.79
# Misc             3.19
# Adventure        2.22
# Name: jp_sales, dtype: float64
#
# Остальные: genre
# Shooter         13.48
# Action          10.58
# Sports           8.55
# Role-Playing     5.38
# Fighting         1.57
# Name: other_sales, dtype: float64

# %%
NA_top_genre.plot(x='genre', y='na_sales', kind='bar', figsize=(6,2),
                  grid=False, title='Топ-5 в Северной Америке',
                  xlabel="Жанр", ylabel='Число продаж, млн копий');

# %%
EU_top_genre.plot(x='genre', y='na_sales', kind='bar', figsize=(6,2),
                  grid=False, title='Топ-5 в Европе',
                  xlabel="Жанр", ylabel='Число продаж, млн копий');

# %%
JP_top_genre.plot(x='genre', y='na_sales', kind='bar', figsize=(6,2),
                  grid=False, title='Топ-5 в Японии',
                  xlabel="Жанр", ylabel='Число продаж, млн копий');

# %%
OT_top_genre.plot(x='genre', y='na_sales', kind='bar', figsize=(6,2),
                  grid=False, title='Топ-5 в остальном мире',
                  xlabel="Жанр", ylabel='Число продаж, млн копий');

# %% [markdown]
# <a id='genres_top'></a>
# **Япония** сильно выделяется на фоне мира. **Шутеры здесь на третьем месте**. При этом их доля всего **3.79 млн** копий. **На первом месте экшн - 23.05 млн. На втором ролевые игры - 13.41 млн**.
# 4 и 5 место занимают Misc - 3.19 и Adventure - 2.22 млн копий.
#
#
# Во всём мире **на первом месте шутеры**: (NA - 48.18, EU - 40.28, другие - 13.48.
#
#
# **На втором месте в мире экшн**: (33.68, 34.82, 10.58 с тем же делением по регионам).
#
#
# **И спортивные игры на третьем месте**: (26.31, 27.82, 8.55 на Америку, Европу и другие страны).
#
#
# **Во всех регионах также есть ролевые игры**. Их доля достоточно высока относительно других, но всё же они на 4 месте всюду, кроме Японии: NA - 19.82, EU - 17.21, другие - 5.38 млн копий.
#
#
# А вот по **пятому месту** везде свой набор:
# Северная Америка: Misc - 5.58.
# Европе: Racing - 6.52.
# Остальные: Fighting - 1.57.
#
#
# Объяснить отличие японцев можно тем, что они любители думать, размышлять. Плюс их менталитет, философия. Умение быть сдержанными. То же про ролевые игры. Шутеры занимают третье место, но их доля настолько невелика, что просто не имеет особого значения. Для них нет ничего хуже, чем бездумные игры.
#
# Что касается остального мира, то в нём ещё преобладает агрессия, а потому шутеры занимают первые места. Прекрасно снимая стрессы и не заставляя слишком много размышлять, шутеры прекрасный способ слить агрессию. Однако приключения не так и сильно отстают.

# %% [markdown]
# ### Влияние рейтинга ESRB на продажи в отдельном регионе
#
# <a id='esrb'></a>

# %% [markdown]
# Сначала соберём отдельный сет `esrb_data`, в котором будут данные только со значениями. Можно, конечно, заменить на `unknowun`, но это будет победитель. А так есть чёткая картина. Однако думаю, что сделаю для сравнения и с `unknown`.

# %%
# В переменную даём строки, в которых не истина, что ячейка rating пуста (боже, что с моим русским! :))
esrb_data = data.query('(~rating.isna()) and year_of_release >= 2015')
esrb_data.head(2)
# Out:
#        name platform  year_of_release   genre  na_sales  eu_sales  jp_sales  \
# 77  FIFA 16      PS4             2015  Sports      1.12      6.12      0.06
# 94  FIFA 17      PS4             2016  Sports      0.66      5.75      0.08
#
#     other_sales  critic_score  user_score rating  total_sales
# 77         1.28          82.0         4.3      E         8.58
# 94         1.11          85.0         5.0      E         7.60

# %%
esrb_data.shape
# Out:
# (595, 12)

# %% [markdown]
# Получил 595 строк.

# %%
no_rate_data = data.copy()
no_rate_data.head(2)
# Out:
#                 name platform  year_of_release     genre  na_sales  eu_sales  \
# 0         Wii Sports      Wii             2006    Sports     41.36     28.96
# 1  Super Mario Bros.      NES             1985  Platform     29.08      3.58
#
#    jp_sales  other_sales  critic_score  user_score rating  total_sales
# 0      3.77         8.45          76.0         8.0      E        82.54
# 1      6.81         0.77           NaN         NaN    NaN        40.24

# %%
no_rate_data.shape
# Out:
# (16443, 12)

# %%
no_rate_data['rating'] = no_rate_data['rating'].fillna('unknown')

# %%
no_rate_data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# 0     28.96      3.77         8.45          76.0         8.0        E
# 1      3.58      6.81         0.77           NaN         NaN  unknown
# 2     12.76      3.79         3.29          82.0         8.3        E
# 3     10.93      3.28         2.95          80.0         8.0        E
# 4      8.89     10.22         1.00           NaN         NaN  unknown
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# ...

# %%
no_rate_data_2 = no_rate_data.query('year_of_release >= 2015')

# %%
no_rate_data_2.shape
# Out:
# (1108, 12)

# %%
# Посчитаем количество всех игр каждого рейтинга вообще

for rate in esrb_data['rating'].unique():
    print('Количество игр с рейтингом', rate, '-', esrb_data.loc[esrb_data['rating'] == rate]['rating'].count())
print()    
# А потом посчитаем игры с рейтиногом и без

for rate in no_rate_data_2['rating'].unique():
    print('Количество игр с рейтингом', rate, '-', no_rate_data_2.loc[no_rate_data_2['rating'] == rate]['rating'].count())
# Out:
# Количество игр с рейтингом E - 153
# Количество игр с рейтингом M - 149
# Количество игр с рейтингом T - 192
# Количество игр с рейтингом E10+ - 101
#
# Количество игр с рейтингом unknown - 513
# Количество игр с рейтингом E - 153
# Количество игр с рейтингом M - 149
# Количество игр с рейтингом T - 192
# Количество игр с рейтингом E10+ - 101

# %%
# Визуализация по очищенным данным, где рейтинг указан. 
for rate in esrb_data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']]:
    (esrb_data
     .pivot_table(index='rating', values=rate, aggfunc='sum')
     .plot(x='rating', y=rate, kind='pie', figsize=(4, 3), legend=False)
    );
    (esrb_data
     .pivot_table(index='rating', values=rate, aggfunc='sum')
     .plot(kind='bar', figsize=(3, 2))
    );

# %%
# Информация по грязным данным, где отсутствует рейтинг во многих записях

for rate in no_rate_data_2[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']]:
    (no_rate_data_2
     .pivot_table(index='rating', values=rate, aggfunc='sum')
     .plot(x='rating', y=rate, kind='pie', figsize=(4, 3), legend=False)
    );
    (no_rate_data_2
     .pivot_table(index='rating', values=rate, aggfunc='sum')
     .plot(kind='bar', figsize=(3, 2))
    );

# %% [markdown]
# # О возрастном цензе:
#
# <details>
#   <summary>Кликни, чтобы открыть</summary>
#
#
#
# - **EC**: «Early childhood» — «Для детей младшего возраста». Игр: 8.
#
#     Игра подходит для детей **от 3 лет** и не содержит материалов, которые родители могли бы счесть неподходящими. Продукты, получившие данный рейтинг, изначально разрабатываются для детей и обычно представляют собой развивающие игры. Некоторые усложнённые развивающие игры могут иметь рейтинг «Everyone».
#
#
# - **E**: «Everyone» — «Для всех». Игр: 3924.
#
#     Содержание вполне подходит **для всех возрастов**. Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Первой игрой, которая получила данный рейтинг, стала The Simpsons Cartoon Studio, выпущенная в 1996 году. Первоначально "K-A" ("Kids to Adults").
#
#
# - **E10+**: «Everyone 10 and older» — «Для всех от 10 лет и старше». Игр: 1393.
#
#     Проекты с данным рейтингом могут содержать или немного больше мультипликационного или мягкого насилия, или несколько откровенные сцены, или минимальное количество крови.
#
#
# - **T**: Teen» — «Подросткам». Игр: 2905.
#
#     Игра подходит для лиц **от 13 лет**. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики.
#
#
# - **M**: «Mature» — «Для взрослых». Игр: 1536.
#
#     Материалы игры **не подходят для лиц младше 17 лет**. Проекты с данным рейтингом могут содержать достаточно жёстокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории.
#
#
# - **AO**: «Adults Only 18+» — «Только для взрослых». Игр: 1.
#
#     **Нужно отметить**, что это игра Grand Theft Auto: San Andreas	для X-Box, релиз 2005 года. Та же игра имеет менее кровожадный рейтинг (М) для PS2 (релиз 2004), PC (релиз 2005) и X-Box 360 (релиз 2008).
#
#     Содержание игры только для взрослых **старше 18 лет**. Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое, а также сцены с обнажением. Большинство таких игр предназначено для персональных компьютеров. </details>

# %% [markdown]
# <a id='top_esrb'></a>
# По данным, которые очищены от пустот в рейтинге (595 строк за выбранный период), во всех странах, кроме Японии, ярко выражен рейтинг М. В Японии преобладает рейтинг Т (около 8 млн).
#
#
# Если же взять за основу данные, не очищенные от пустот в рейтинге (1108 строк), то преобладание рейтинга М остаётся по регионам, но в Японии `unknown` занимает тут же более 30 млн копий, что почти в 4 раза больше рейтинга T.
#
#
# Можно сказать, что в Японии игровая индустрия развивается отлично от остального мира, в том числе и офлайн. Кроме того, сама индустрия заточена не только под продажи по всему миру супер-хитов типа, но каких-то игр для своего региона. Также, как мы помним, в Японии шутеры на третьем месте, а именно они чаще всего имеют категорию М. Что же касается ролевых игр и приключений, то вполне нормально для них в том числе и рейтинг Т. С другой стороны, например, игра Fable III имеет рейтинг ESRB - T, а рейтинг CERO - Z, то есть, 18+. CERO - японский рейтинг. По сути аналог T для Японии это их местный С (от 15 лет) и, возможно, часть B (от 12 лет).
#
#
# Стоит отметить также тот факт, что у нас слишком много пропусков данных. Для всех регионов, кроме Японии, почти столько же, сколько занимает топовый рейтинг. И только в Японии почти 50%. Это говорит о том, что ни рынок Японии, ни их статистика не изучены.

# %%
data[data['rating'] == 'AO']
# Out:
#                               name platform  year_of_release   genre  \
# 875  Grand Theft Auto: San Andreas       XB             2005  Action
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 875      1.26      0.61       0.0         0.09          93.0         8.6
#
#     rating  total_sales
# 875     AO         1.96

# %% [markdown]
# ## Проверка гипотез
# <a id='hyp'></a>
#
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
#
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# ### Проверка гипотезы об одинаковых пользовательских рейтингах  платформ Xbox One и PC
#
# <a id='h1'></a>
#
# За нулевую гипотезу (H0) берём, что они одинаковы.
#
# За альтернативную (H1) - не одинаковы.

# %%
data_15_16.dropna(subset=['user_score'], inplace=True)
results = st.ttest_ind(
    data_15_16.loc[data_15_16['platform'] == 'XOne']['user_score'],
    data_15_16.loc[data_15_16['platform'] == 'PC']['user_score']
)

alpha = .05

print('p-значение:', results.pvalue)
print()
print('Гипотеза: "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"')
print()
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.2778542084733835
#
# Гипотеза: "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"
#
# Не получилось отвергнуть нулевую гипотезу

# %%
# Проверим

print('Среднее для Икс Ван:', data_15_16.loc[data_15_16['platform'] == 'XOne']['user_score'].mean())
print()
print('Среднее для ПК:',data_15_16.loc[data_15_16['platform'] == 'PC']['user_score'].mean())
# Out:
# Среднее для Икс Ван: 6.542148760330578
#
# Среднее для ПК: 6.29642857142857

# %%
data.dropna(subset=['user_score'], inplace=True)
results = st.ttest_ind(
    data.loc[data['platform'] == 'XOne']['user_score'],
    data.loc[data['platform'] == 'PC']['user_score']
)

alpha = .05

print('p-значение:', results.pvalue)
print()
print('Гипотеза: "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"')
print()
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.3039339221792068e-05
#
# Гипотеза: "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"
#
# Отвергаем нулевую гипотезу

# %%
# Проверим

print('Среднее для Икс Ван:', data.loc[data['platform'] == 'XOne']['user_score'].mean())
print()
print('Среднее для ПК:', data.loc[data['platform'] == 'PC']['user_score'].mean())
# Out:
# Среднее для Икс Ван: 6.521428571428572
#
# Среднее для ПК: 7.06631299734748

# %% [markdown]
# ### Проверка гипотезы о разности пользовательских рейтингов  жанров  Action и Sports.
#
# <a id='h2'></a>
#
# За нулевую гипотезу (H0) берём, рейтинги не различаются.
#
# За альтернативную (H1) - рейтинги разные.

# %%
data_15_16.dropna(subset=['user_score'], inplace=True)
results = st.ttest_ind(
    data_15_16.loc[data_15_16['genre'] == 'Action']['user_score'],
    data_15_16.loc[data_15_16['genre'] == 'Sports']['user_score']
)
alpha = .05

print('p-значение:', results.pvalue)
print()
print('Гипотеза: "Средние пользовательские рейтинги жанров Action и Sports не различаются"')
print()
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не удалось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.0012846807938657e-13
#
# Гипотеза: "Средние пользовательские рейтинги жанров Action и Sports не различаются"
#
# Отвергаем нулевую гипотезу

# %%
# Проверим

print('Среднее для Экшн:', data_15_16.loc[data_15_16['genre'] == 'Action']['user_score'].mean())
print()
print('Среднее для Спорта:',data_15_16.loc[data_15_16['genre'] == 'Sports']['user_score'].mean())
# Out:
# Среднее для Экшн: 6.808290155440415
#
# Среднее для Спорта: 5.198780487804878

# %%
data.dropna(subset=['user_score'], inplace=True)
results = st.ttest_ind(
    data.loc[data['genre'] == 'Action']['user_score'],
    data.loc[data['genre'] == 'Sports']['user_score']
)

alpha = .05

print('p-значение:', results.pvalue)
print()
print('Гипотеза: "Средние пользовательские рейтинги жанров Action и Sports не различаются"')
print()
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не удалось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.06480928064420527
#
# Гипотеза: "Средние пользовательские рейтинги жанров Action и Sports не различаются"
#
# Не удалось отвергнуть нулевую гипотезу

# %%
# Проверим

print('Среднее для Экшн:', data.loc[data['genre'] == 'Action']['user_score'].mean())
print()
print('Среднее для Спорта:',data.loc[data['genre'] == 'Sports']['user_score'].mean())
# Out:
# Среднее для Экшн: 7.058129175946549
#
# Среднее для Спорта: 6.951433857539316

# %% [markdown]
# <a id='h0h1resume'></a>

# %% [markdown]
# У нас есть два различных результата для двух гипотез.
#
# 1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
#     1.1. За 2015-2016 годы гипотеза не может быть отвергнута: p-значение: 0.278, а средние выборок равны: 6.54 и 6.3 соответственно.
#
#     1.2. За весь период гипотезу отвергаем, поскольку p-значение: 1.3039339221792068e-05. Средние выборок равны: 6.52 и 7.07. Всё же разница ощутимее.
#
# <hr>
#
# 2. Средние пользовательские рейтинги жанров Action и Sports разные. Для **Н0 берём гипотезу о том, что данные одинаковы**, а Н1 - разные.
#
#     2.1. За 2015-2016 годы гипотеза Н0 отвергнута, при этом p-значение: 1.0012846807938657e-13, а средние выборок 6.81 и 5.2.
#
#     2.2. За все года гипотезу Н0 отвергнуть не удалось, p-значение: 0.06480928064420527, а средние всего-то с разницей в единицу: 7.06 и 6.95 (Экшн и Спортс).
#
# ---

# %% [markdown]
# # Итог исследования
# <a id='resume'></a>

# %% [markdown]
# # Цели исследования
#
# - Выявить определяющие успешность игры закономерности.
# - Спрогнозировать потенциальную популярность продуктов для планирования рекламный кампаний.
#
# ---
#
# Для изучения были предоставлены [данные](#datas_info) в файле формата `csv` - `games.csv`, состоящие из 16715 строк и 11 колонок. Всего наименований игр - 11425. Разница между числом строк и игр говорит лишь о том, что многие игры выходят на разных платфрмах.
# Типы данных `object`, `float64`.
#
# ---
#
#
# # Первичное изучение данных
#
#
# 1. **Дубликаты**. Нет ни одного явного дубликата. Возможно, есть неявные. Часть игр выходила на разных платформах и, возможно, имела переиздания. Например, Need for Speed: Most Wanted встречается 12 раз. Проверка показала, что есть совпадение по платформам, но разные годы релизов. Не исключаю, что всё же есть 2-3 дубля по другим играм, но есть записи, где присутсвует некое отличие, а потому записать игру в дубль нет возможности.
#
#     *Кроме того, у нас не было цели в проекте. А значит считается, что данные чисты*
#
#
# 2. **Пропуски**. Есть по два в названиях и жанрах, а также 269 в годе релиза. Первые два в принципе не нужны и удалены сразу, 269 записей удалены, поскольку годы имеют значение для анализа. Однако данные сохранены в резерве - переменная `reserved_data`.
#
#     Огромное число пропусков в оценках игроков (6701) и критиков (8578), а также в возрастном рейтинге (6766). Это тоже будет сильно влиять на результат, а потому ожидать от прогноза 100% точности не стоит. Будет много предположений.
#
#
# 3. **Платформы**. Проверка по интернету говорит, что все платформы есть.
#
#     - GB, вероятно, Game Boy.
#     - DS == некоторые приставки от Nintendo.
#     - 2600 == Atari 2600, что не удивительно с учётом уников лет.
#     Перечислять всё смысла нет, но всё в списке есть в игровых платформах. Об этом говорят как сайт [vgtimes](https://vgtimes.ru/games/platforms/), так и поиск [Яндекс](ya.ru).
#
#
# 4. **Годы**. С 1980 по 2016 годы.
#
#
# 5. **Рейтинги**:
#
#       **Критиков**: от 13 до 98.
#
#       **Игроков**: от 0 до 9.7. Значит ли ноль, что нет оценок или это именно такой балл, неизвестно. В описании данных ничего об этом нет. Так как NaN - верный пропуск за счёт отсутсивия данных, сложно считать именно этот ноль отстутствием оценок.
#
#       **Возрастные**: от "Для всех" (E) до "Только для взрослых" (AO), которые в основном предназначены для PC. Ещё есть RP, что обозначает, что игра на момент определения возрастного рейтинга находилась на оценке в ESRB.
#
# ---
#
# [Немного статистики](#describe).
#
# **Среднее** число:
#
#     - продаж (млн):
#
#         - в Северной Америке: 0.264028
#         - в Европе: 0.145937
#         - в Японии: 0.078492
#         - по другим странам: 0.047596
#
#     - оценок (баллы):
#
#         - критики: 69 из 100
#         - игроки: 7 из 10
#
# **Минимальное** число:
#
#     - продаж (млн):
#
#         - в Северной Америке: 0
#         - в Европе: 0
#         - в Японии: 0
#         - по другим странам: 0
#
#     - оценок (баллы):
#
#         - критики: 14 из 100
#         - игроки: 1.5 из 10
#
# **Максимальное** число:
#
#     - продаж (млн):
#
#         - в Северной Америке: 41.360000
#         - в Европе: 28.960000
#         - в Японии: 10.220000
#         - по другим странам: 10.570000
#
#     - оценок (баллы):
#
#         - критики: 98 из 100
#         - игроки: 9.7 из 10
#
#
# **С чем может быть связан ноль?** Скорее всего, отсутствие стататистики. Округление у нас даёт 6 цифр после запятой, то есть до единиц. И даже 1 проданная игра была бы 0.000001. Значит, это что-то другое.
#
#
# Данные по нулям таковы:
#
# - Северная Америка: 4448
# - Европа: 5766
# - Япония: 10299
# - Остальные: 6492
#
#
# Предположу, что здесь есть сочетание храненения информации давних лет, недоступности информации и чисто региональные особенности. Начну с последнего. Здесь меньше всего выделяется Америка, которая является в какой-то степени законодателем в игровой индустрии. Кроме того, есть игры, которые компании делают в принципе для рынков иных стран. Ну и какая-то часть данных может быть как утрачена, так и не предоставлена. Хотя мне тут больше видится второе.

# %% [markdown]
# # Предобработка данных
#
# Были [обработаны](#preprocessing):
#
#
# 1. [Наименования столбцов](#rename). Приведены к нижнему регистру.
#
#
# 2. [Пропуски](#nans). Удалена 271 строка. Это 1.62% от числа записей. Не могу сказать, что масса критична. Особенно в сравнении с пропусками в оценках и возрастном рейтинге.
#
#
# 3. [Оценки пользователей](#tbd). Заменено значение `tbd` в рейтинге пользователей. Вместо него выставил `NaN`.
#
#
# 4. [Возрастной рейтинг](#age_rating). Я заменил **К-А** на **Е**, так как этот рейтинг уже не актуален, и именно **Е** его заменил. Ещё я удалил строку с рейтингом **RP**, поскольку этот рейтинг для игр, которые ещё не вышли в продажу. Он используется для рекламных кампаний игр.
#     С этим удалением получилось уже  272 строки (из 16715). Это 1.63%.
#
#
# 4. [Смена типов данных](#types). Заменил в столбце `year_of_release` тип данных на `int`, ранее был тип `float`. В столбце `user_score` изменил тип данных на `float`, ранее был `object` за счёт значения `tbd`.
#
# ---
#
# *Почему не поменял `user_score` и `critic_score` на `int`? В данных пропуски и конвертация в `int` нереальна. Если есть какие-то хитрые способы, на нашёл.*
#
# ---
#
# 5. [Добавил](#sum) в таблицу 12-й столбец с суммой всех продаж для каждой строки. То есть для каждой игры для каждой платформы.
#
# **ПРОПУСКИ** могли возникнуть вследствие нескольких причин. Одна из них чисто техническая - при сохранении или копировании данных возникли ошибки, которые и привели к пропускам. Однако число пропусков сильно разнится, что говорит не в пользу гипотезу.
#
# Наиболее вероятной считаю причины следующие:
#
# 1. Сама система рейтингов возникла лишь в 1990-х годах, а к 2003 году оценки получили всего около 8000 игр. То есть, на момент выгрузки данных (2016 год) рейтинги могли быть не составлены для многих старых игр.
#
# 2. Источник, в котором брали информацию об играх, не имел некоторых данных по неизвестным нам причинам. Например, [срез игр](#nans_2), начиная с 2003 года показывает 4288 пропусков. Что может говорить именно об отствии данных в источнике.

# %% [markdown]
# ## Исследовательский анализ
#
#
# I. [Проверка количества игр за различные периоды](#periods).
#
# [График](#game_grafik)
#
# В 1981 и 1982 годах был "бум" - 46 и 36 игр, соответственно. Вероятно, на волне развития технологии. Далее число игр снизилось и держится в диапазоне 14-17 с одни выпадом до 21 в 1986 году. С 1991 рост до 41, к 1993 уже 60 игр. Затем резкий скачок до 121 игры в 1994 году, в 1995 уже 219 игр. Скорее всего, связать это можно с несколькими факторами.
#
# Во-первых, развитие как самих технологий и, соответственно, приставок и РС. Во-вторых, именно в те годы был переход с 8-битных игр на 32-битные и даже 64-битные. А это уже другие графика и возможности. Плюс то поколение, которому не было сложно освоиться с техникой, а, значит, и покупать игры.
#
# Далее идёт постепенный небольшой прирост до 2001 года - 482	игры. Резкий скачок почти в два раза, небольшое пададение и снова постепенный рост. Пиковые годы - 2008 (1427 игр) и 2009 (1426 игр). Это огромное число шутеров, RGP и квестов. Рост явно обусловлен более доступными ПК, за счёт удешевления процессоров и прочих комплектующих. Отсюда рост спроса на развлечения. А потом наблюдается спад. Причём довольно значительный: если в 2011 году было выпущено 1135 игр, то в 2012 только 653. Связано ли это с тем, что издатели перешли на более качественный контент, сложный геймплей, сюжет и прочие умные слова геймеров?
#
# Плюс к этому пришли сетевые игры. Как раз в пики. И многие из них до сих пор популярные, получают аддоны, обновления, но не перестают быть актуальными.
#
# К вопросу о важности данных. Они, безусловно, важны, но нам достаточно взять **2015 и 2016** годы, чтобы сделать прогноз.
#
# ---
#
# II. [Изменения продаж игр по платформам](#platform)
#
# Я сознательно взял PC (ПК).
#
#
# Ярчайший лидер - **PS2**. Она стоит в большом отрыве от остальных. Стоит учесть, что она, как и первая версия, были на тот момент феноменом, что и послужило такой популярности. Тем более, что первый действительно достойный конкурент появился только на пике продаж PS2 (см. график). Остальные лидеры: **X360, PS3, Wii, DS, PS**.
#
#
# На [графике](#platforms_plot_1990) заметны:
#
#
# 1. Качелеобразное движение линии **ПК** (оранжевый). Есть всплеск после 2005 года с пиком на 2011 год, а затем всё вернулось к обычным показателям. Цикл непрерывен.
#
#
# 2. Выход на рынок принципиально нового игрового элемента - приставки **PlayStation** от Sony (зелёный). Основная масса приставок на тот момент: Dendy, Sega, Sega 2, Super Nintendo. Это приставки от 8 до 64 бит. И тут в 1994 году вышла новая приставка с графикой 3D. Пик пришёлся на 1998 год, когда компания завоевала все страны. Спад популярности примерно в 2003 году. **Жизненный цикл 9 лет**.
#
#
# 3. **PlayStation 2** (красная) вышла в 2000 году, уже ближе к концу года она уровне первой версии, к тому моменту сдающей позиции. Пики пришлись на 2002 и 2004 годы. Не очень понятен провал в 2003 году, поскольку на тот момент конкурентов просто не было, а единственная альтернатива тех лет - **3DO** - на 4-м месте с конца. Падение популярности довольно длительное - до 2011 года. Стоит также отметить, что её пика никто не перебил. **Жизненный цикл 11 лет**.
#
#
# 4. **Nintendo DS** (синий) выходит в 2004 году. За год набирает довольно большую популярность. В 2006 году просадка за счёт просто триумфального выхода **Wii** от Nintendo (о ней ниже, п. 6). Плюс в 2005 вышла **Xbox 360** (о ней в п. 5), которая также отжала часть пользователей. В районе 2007 года идёт заметен мощный рывок вверх, а затем и полноценный спад до 2013 года. **Жизненный цикл 9 лет**.
#
#
# 5. **Xbox 360** от Microsoft (сиреневый) вышла в 2005 году. Первый пик в 2008 году, однако не перебила популярность **Nintendo DS** и **Wii**. Второй пик в 2010 году. В это время - наиболее популярная приставка и самые большие продажи игр для неё. Стоит отметить, что **Wii** резко летит в закат, **Nintendo DS** ещё ниже, а почти на уровне с **Xbox 360** стоит **PlayStation 3** (п. 7). И последняя уже на подоходе к пику популярности. К слову, не превысила уровень **Xbox 360**. **Жизненный цикл 11 лет**.
#
#
# 6. **Wii** - приставка от Nintendo. Стартовала в 2006 году просто феноменально, судя по графику. Её начальный уровень был выше, чем небольшое проседание **Nintendo DS**. Связано с гениальным маркетингом. Приставку ждали так, что ещё на этапе предзаказа всё раскупили. Пик пришёлся на 2009 год. Сама приставка занимает второе место после **PS2**. Довольно быстрый спад (как и у всех) до какого-то момента (2013), а потом медленное угасание интереса до 2016 года. **Жизненный цикл 10 лет**.
#
#
# 7. **PlayStation 3** (фиолетовый) стартовала в 2006 и за два года довольно быстро захватила свою часть аудитории, однако рост в 2008 году замедлился. При этом в том же году усилися рост популярности **Wii**, чуть позже, но всё же рядом пошли на падение спроса **Xbox 360** (с первого своего пика) и ускорилось падение популярности **Nintendo DS**. **Жизненный цикл 10 лет**
#
# Возможно, пики 2008 года стоит связать с кризисом. Люди в кризис ищут утешения в развлечениях.
#
# <hr>
#
# С выходом **Nintendo DS** популярность приставок хоть и отличается, но остаётся примерно на одном уровне. За исключением **Wii**. Пики, скорее всего, связаны с выходом некоторых игр, из-за которых многие готовы покупать приставки / консоли. Кроме прочего, нельзя забывать про маркетинг, который может разовыми акциями создать довольно большие продажи. Что стоит за пиками и довольно резкими чертами линий графика, можно узнать, лишь изучив огромный пласт информации за весь исследуемый период.
#
# <hr>
#
# **Жизненный цикл** выбранных приставок и консолей от 9 до 11 лет. Характерной черты для выхода нет. **PlayStation** была первой приставкой и до момента выхода **PlayStation 2** прошло 6 лет. Уже через 4 года вышла **Nintendo DS**, а потом 2005 (одна) и 2006 (две). Можно сказать лишь, что сроки разработки нового продукта сократились. С другой стороны - производители разные. Та же Sony выпустила **PlayStation 3** только через 6 лет после запуска второй.
#
# Второй график показывает сокращение жизненного цикла новых приставок.
#
# Могу предположить, что в среднем процесс разработки, вне зависимости от начала, занимает примерно 5 лет от момента выхода актуальной версии. При этом работа над новой консолью начинается задолго до окончания жизненного цикла актульного продукта.
#
# ---
#
# III. [Данные 2015-2016 годов](#15_16)
#
#
# В выбранном периоде (2015 и 2016 годы) - 1108 позиций. Почему я выбрал именно два года? Так будет более заметно, растёт или падает.
#
# Лидируют PlayStation4 (PS4), Xbox One (XOne), Nintendo 3DS (3DS). PS4 с ярко выраженным отрывом - более, чем в 4 раза от Nintendo и более, чем в 2.5 раза от XOne.
#
# Собственно, непотопляемый PC на 6 месте в этом зачёте. Если брать только 2016 год, то уже на 4-м. А вот приставки с 4 и 5 мест ушли вниз, причём число продаж игр для них сократилось в 5 и 6 раз. То есть **WiiU** и **PS3** явные аустайдеры.
#
# Потенциально прибыльными будут Xbox One (XOne), Nintendo 3DS (3DS). Прибыль точно принесёт PlayStation4 (PS4). Но на последнем графике очевидно довольно прямое падение. Не стоит забывать, что Xbox One в периоде затухания, а вышла в 2013 году. Потенциально есть шанс на выход новой версии платформы в 2017-2018 годах. То же касается и других платформ. Nintendo 3DS вышла в 2011 году, уже находится в стадии затухания. Не исключён выход новой консоли. Равно как и с моделями от Sony.
#
#
# *История говорит, что всё так и получилось.*
#
# Здесь следует изучить анонсы производителей и издателей, изучить, как соотносились их анонсы с реальностью в предыдущие годы, а на основе уже более полной информации занимать позицию. Периоды затухания несколько уменьшились, а потому новые релизы также могут стать с менее длительными промежутками.
#
#
# **Это очень интересно, что Sony столь явный лидер рынке индустрии игровых консолей. Его было бы интересно изучить. Что это? Маркетинг? Дань первому опыту?**
#
# ---
#
# IV. [Диаграммы размаха](#diagramma_top)
#
# - **PS3**. Лидер. Позиции сдал.
#     Минумум: 3.60, максимум: 156.78. Первый квартиль: 34.36, третий квартиль: 124.73. Среднее: 84.67 слишком сильно отличается от медианного значения - 107.36. Этот вопрос, возможно, стоит изучить отдельно. Возможно, это за счёт начала на довольно низких позициях.
#
#
# - **PS4**.
#     Минумум:25.99, максимум: 118.90. Первый квартиль: 58.43, третий квартиль: 104.72. Среднее: 78.54 довольно-таки отличается от медианы - 84.63.
#
#
# - **3DS**.
#     Минумум: 15.14, максимум: 63.20. Первый квартиль: 31.78, третий квартиль: 55.27. Среднее: 42.97 имеет заметное отличие от медианы - 47.56.
#
#
# - **XOne**.
#     Минумум: 18.96, максимум: 60.14. Первый квартиль: 24.35, третий квартиль: 55.59. Среднее: 39.83 почти не отличается от медианы - 40.11.
#
#
# - **WiiU**.
#     Минумум: 15.14, максимум: 63.20. Первый квартиль: 31.78, третий квартиль: 55.27. Среднее: 42.97 тоже имеет заметное отличие от медианы - 47.56.
#
#
# Стоит учитывать, что все приставки появились в разные годы, а потому информация выше может быть спорной, однако, несмотря на разные годы выхода на рынок, все они находятся либо в почти полном закате, либо на стадии заката. Даже, если взять за основу промежуток с 2013 года, получится, что **PS3** лидирует. Её показатель был бы под 100, хотя у остальных - меньше 60. Это можно заменить на [графике](#falling), который я сделал ранее. Кроме того, нас всё же интересует жизненный цикл, а не его часть.
#
# По ссылке с диаграммами их две: **за весь период и для 2015-2016 годов**. Поскольку эти диаграммы не требуются для построения выводов и гипотез, я описал первую, используя в том числе `describe`. Можно сказать, что мало отличаются от описанной. Одно большое отличие - приставка **PS3**. Она из огромной коробки превратилась в коробчонку. Остальные немного сдали, но в целом выглядит просто информацией за меньший период. Это объяснимо в том числе тем, что **PS3** старше на пять лет.
#
# ---
#
# V. [Влияние отзывов на покупки игр](#corr)
#
# В зачёт идут две относительно перспективных платформы: "PS4", "XOne". Почему именно они? Покажет график ниже. Остальные уже просто не котируются.
#
#
# Из пяти топовых:
# - 3DS в закате. **Можно закупать игры для неё**, но вряд ли стоит сливать сюда весь бюджет.
#
# - WiiU - неудачная замена Wii, которая набрала едва ли 25 млн продаж на своём пике.
#
# - PS3 в топе вообще за счёт 2015 года. И по сути уже кончилась. Как выше сказано, в 2016 году на 4-м месте вообще стоит PC.
#
#
# Две оставшиеся:
# - PS4 уходит в закат, но имеет шанс на пик. Хотя шанс на это примерно 1 из 5. Уже писал про потенциальные выходы новых платформ.
#
# - XOne тоже уходит в закат, но пока ещё имеет некоторую актульальность, как и PS4.
#
# **Выводы**:
# По оценкам игроков по двум платформам (**PS4 и XOne**) корреляция явно стремится к нулю (-0.06 и -0.04 сответственно) при этом с отрицательной тенденцией.
#
# Связь между покупками и оценками критиков тоже имеет достаточно выраженную связь: 0.39 и 0.43 сответственно.
# Отсюда два посторонних и интересных вопроса:
# 1. Почему оценки игроков не влияют на покупки, если по сути они одинаковы с оценками критиков чаще всего?
# 2. Не ставят ли игроки оценки играм, основываясь на уже известных им оценках критиков?
#
# **[Соотношение с продажами на других платформах](#other_platforms)**.
#
# <a id='vivod_5'></a>
#
# Вряд ли можно делать адекватные сравнения для приставок 80-90 годов и суперсовременных платформ. Среди представленных есть и карманные, и стационарные. Некогда в зависимости от платформы игра на одном картридже могла быть как одна (Ninendo, Sega), так и несколько (Dendy). При этом сами игры были совершенно иными. Стоит отметить, что ворастные ограничения начали вводить в 1994 году. Да и то только в США и Канаде. К началу 2003 года рейтинги получили только 8000+ игр, то есть, достаточно небольшая часть. В том же 2003 заработал PEGI, европейский аналог ESRB. Японская ассоциация - CERO - работает с 2002 года. Потому некоторая часть игр покупалась и использовалась детьми, которым после введения ограничений игру не купили бы скорее всего. А это довольно много миллионов копий Mortal Kombat, например. С другой стороны, есть информация, что некоторая часть игр продавалась с возрастным цензом, принятым для кинопроката. То есть какие-то ограничения местами были.
#
#
# Теперь к самим продажам. Размах по популярным приставкам / консолям они **сопоставим**. По основному размаху отличия есть, а вот по выбросам очень похожи: на всех видны большие выбросы. Это мегапопулярные игры. Например, для NES - Super Mario Bros. (40,24 млн экз.) и Super Mario Bros. 3 (17,28 млн экз.); у SNES - 	Super Mario World, 20 млн копий (к 25 июня 2007 г.). А выброс Wii объясняется простейшим образом: игра Wii Sports продавалась вместе с консолью (кроме Японии и Южной Кореи), а потому продали 79,6 млн копий.
#
#
# В то же время общее число проданных игр показывает достаточно большую разницу. О разнице в популярности и сроках писал ранее.
#
#
# По всем платформам создаётся впечатление, что были десятки или сотни игр, которые продавались просто потому, что играть нужно во что-то. И были некие культовые игры, продаваемые многомиллионными тиражами.
#
#
# ***Вообще, очень занятный график. У всех есть выборосы за верхними границами. И довольно много. Значит ли это, что не так что-то с данными и вообще всё неправильно? Увидим в комментарии ревьюера. Может, я всё сделал неверно?***
#
#
# Интересная картина. **PS3** в своих корреляциях вполне похожа на **PS4 и XOne**. Хотя у нее по игрокам положительная и всё же измеряется десятыми долями. Это приставки от Sony и Microsoft. А приставки от Nintendo имеют, во-первых, более высокую корреляцию по оценкам игроков, чем критиков, а во-вторых, они достаточно схожи. Это могло бы положить начало новому исследованию по уровням доверия игроков в зависимости от предпочтения брендов.
#
# Собственно, сама кореляция.
#
# **WiiU** заметна связь в обоих случаях (игроки 0.40 и критики 0.35)
#
#
# **3DS** - корреляция совсем не очевидна и стремится ближе к нулю. Но всё же какая-то едва заметная зависимость есть (игроки 0.2 и критики 0.18).
#
#
# **PS3** - практически нет по оценкам игроков, но средняя зависимость от оценок критиков (игроки 0.13 и критики 0.43).
#
# **PC** - для уверенной связи между оценками игроков и продажами корреляция маловата, но какая-то небольшая есть. Связь между оценками критиков и продажами заметнее.
#
# ---
#
#
# VI. [Общее распределение по жанрам](#genres).
#
# **Самые прибыльные жанры и различия в жанрах по продажам**
#
# **2015-2016 годы**:
#
#
# - Shooter
# - Action
# - Sports
# - Role-Playing
#
# С огромным отставанием:
# - Misc
#
# Скорее всего, этот жанр даже стоит исключить, оставив только 4 топа.
#
# Шутеры и экшн идут довольно ровно. С большим отрывом идут спорт и ролевые. Но этот открыв не настолько страшен, как позиция Misc.
#
#
# **Всё время**:
#
#
# - Action
# - Sports
# - Shooter
# - Role-Playing
# - Platform
#
# ---
#
# В пяти популярных жанрах перемены небольшие. Три жанра поменялись местами, а один жанр выбыл, его место занял новый, став пятым в списке за два года. Впрочем, в общем зачёте он как раз шёл шестым.
#
#
# Перестановки в принципе идут всё время. И Platform вошёл в общий зачёт только за счёт своего солидного возраста, потеснив Misc, возникший в 1991 году.
#
#
# Собственно, первые три места до 2015 года были распределены так:
#
# - Action
# - Sports
# - Shooter
#
# 4 и 5 места делили Misc и Role-Playing. Ролевые, как я понимаю, это RPG, MMORPG и прочее. Так и не узнал, что это за жанр. Судя по классификации 1984 года, это может быть сокращение от Miscellaneous, то есть, не вошедшее в предыдущие жанры. Но так ли это? Аркады, головоломки, квесты и прочее?
#
# ---
#
# Наблюдается заметный рост во всех жанрах за счёт интенсивного развития индустрии, однако Platform идёт в самом низу, а вот Action и Sports растут просто феноменально. Что и не удивительно. В экшн входят игры по мотивам культовых фильмов, спорт сам по себе набирает популярность (особенно футбол, который соккер). Что касается шутеров, они растут куда медленнее. И в последние два года вылезли лишь за счёт спада по двум первым позициям. Плюс развитие серий Far Cry и Call of Duty, у которых миллионы фанатов.
#
#
# На графике за 6 лет (с 2010 по 2016 годы) выраженное падение. Именно тут в первой половине 2015 года шутеры выходят на первый план. Выход Star Wars Battlefront и Fallout 4 вполне могут объяснить, почему падение популярности жанра меньше, чем у остальных. А спорт они обогнали ещё в начале 2010 года.
#
#
# Теперь по самым неприбыльным жанрам. Это их список в разные периоды на разных местах:
#
# - Puzzle
# - Strategy
# - Simulation
# - Adventure
# - Fighting
#
# Кроме 2015-2016 годов. Там вошли **Platform** и **Racing** вместо Adventure и Fighting.
#
#
# Puzzle, Strategy, Adventure не набрали и 250 млн продаж каждый, а Fighting и Simulation - до 500 млн копий.

# %% [markdown]
# # Портрет пользователя по регионам
#
# I. [ТОП-5 популярных платформ на 2015-2016 годы для каждого региона](#top_5_plat)
#
# <a id='top_5_plat_reg'></a>
# - **Северная Америка**:
#
#    1. **PS4** aka PlayStation 4 от Sony, 63.86 млн.
#    2. **XOne** от Microsoft - 50.30 млн
#    3. **3DS** от Nintendo с 10.31 млн
#    4. **WiiU** от Nintendo и 8.86 млн
#    5. **X360** с 8.05 млн от Microsoft
#
#
# - **Европа**:
#
#    1. **PS4** - 83.54 млн
#    2. **XOne** - 28.10 млн
#    3. **PC** - 9.10 млн
#    4. **3DS** - 7.39 млн
#    5. **PS3**, то есть PlayStation 3 (Sony), 7.30 млн
#
#
# - **Япония**:
#
#    1. **3DS** - 23.55 млн
#    2. **PS4** - 12.05 млн
#    3. **PSV**, известная как PlayStation Vita, 8.41 млн
#    4. **PS3** - 4.97 млн
#    5. **WiiU** - 4.12 млн
#
#
# - **Остальной мир**:
#
#    1. **PS4** - 28.70 млн
#    2. **XOne** - 7.71 млн
#    3. **PS3** - 2.49 млн
#    4. **3DS** - 1.67 млн
#    5. **WiiU** - 1.48
#
# ---
#
# **PS4** лидирует во всём мире, за исключением Японии, где у неё второе место. Столь явное отличие не совсем понятно, так как со второго по четвёртое места стоят изделия фирмы Sony. И только на пятом снова Nintendo с WiiU. Впрочем, в Японии лишь два реальных игрока и рынок по сути поделён примерно 50/50.
#
#
# В **Японии** в ТОП-5 нет американских приставок.
#
#
# В **Северной Америке** рынок делится между изделиями трёх компаний (Sony, Microsoft и Nintendo), причём **XOne** довольно слабо отстаёт от **PS4**.
#
#
# Отличилась **Европа**. В ней в ТОП-5 вошли **ПК** (PC). Их немного, но они занимают третье место после **PS4** и **XOne**.
#
#
# **Остальной мир** делят все три компании. Первым идёт **PS4**, за ней с огромным отставанием в 3.7 раза идёт **XOne**.
#
#
# С чем связано? **PS4** на этот момент самая популярная консоль. Её популярность постепенно снижается в сравнении с прошлыми годами, но всё равно пока это весьма большие числа. Её реальный конкурент - **XOne**. За счёт стоимости вероятно. Поскольку по качеству **3DS** приятнее продукта Microsoft.
#
#
# **PSV** есть только в Японии и это чисто географическая причина. Обычная переносная, карманная консоль. Довольно локальный продукт, который очень популярен в Азии, и абсолютно не зашёл в Европе и Америке.
#
#
# **PC** в Европе занимает 3 место. С довольно большой цифрой. Нельзя исключать, что за счёт России, РБ и Украины, где в регионах достаточно много игроков, которые не могут себе позволить покупки консолей.
#
# ---
#
# II. [ТОП-5 популярных жанров по регионам за 2015-2016 годы](#top_5_genre)
#
# **Япония** сильно выделяется на фоне мира. **Шутеры здесь на третьем месте**. При этом их доля всего **3.79 млн** копий. **На первом месте экшн - 23.05 млн. На втором ролевые игры - 13.41 млн**.
# 4 и 5 место занимают Misc - 3.19 и Adventure - 2.22 млн копий.
#
#
# Во всём мире **на первом месте шутеры**: (NA - 48.18, EU - 40.28, другие - 13.48.
#
#
# **На втором месте в мире экшн**: (33.68, 34.82, 10.58 с тем же делением по регионам).
#
#
# **И спортивные игры на третьем месте**: (26.31, 27.82, 8.55 на Америку, Европу и другие страны).
#
#
# **Во всех регионах также есть ролевые игры**. Их доля достоточно высока относительно других, но всё же они на 4 месте всюду, кроме Японии: NA - 19.82, EU - 17.21, другие - 5.38 млн копий.
#
#
# А вот по **пятому месту** везде свой набор:
# Северная Америка: Misc - 5.58.
# Европе: Racing - 6.52.
# Остальные: Fighting - 1.57.
#
#
# Объяснить отличие японцев можно тем, что они любители думать, размышлять. Плюс их менталитет, философия. Умение быть сдержанными. То же про ролевые игры. Шутеры занимают третье место, но их доля настолько невелика, что просто не имеет особого значения. Для них нет ничего хуже, чем бездумные игры.
#
# Что касается остального мира, то в нём ещё преобладает агрессия, а потому шутеры занимают первые места. Прекрасно снимая стрессы и не заставляя слишком много размышлять, шутеры прекрасный способ слить агрессию. Однако приключения не так и сильно отстают.
#
# ---
#
# III. [Влияние рейтинга ESRB на продажи в отдельном регионе](#esrb)
#
# **О возрастном цензе**:
#
# <details>
#   <summary>Кликни, чтобы открыть</summary>
#
#
# - **EC**: «Early childhood» — «Для детей младшего возраста». Игр: 8.
#
#     Игра подходит для детей **от 3 лет** и не содержит материалов, которые родители могли бы счесть неподходящими. Продукты, получившие данный рейтинг, изначально разрабатываются для детей и обычно представляют собой развивающие игры. Некоторые усложнённые развивающие игры могут иметь рейтинг «Everyone».
#
#
# - **E**: «Everyone» — «Для всех». Игр: 3924.
#
#     Содержание вполне подходит **для всех возрастов**. Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Первой игрой, которая получила данный рейтинг, стала The Simpsons Cartoon Studio, выпущенная в 1996 году. Первоначально "K-A" ("Kids to Adults").
#
#
# - **E10+**: «Everyone 10 and older» — «Для всех от 10 лет и старше». Игр: 1393.
#
#     Проекты с данным рейтингом могут содержать или немного больше мультипликационного или мягкого насилия, или несколько откровенные сцены, или минимальное количество крови.
#
#
# - **T**: Teen» — «Подросткам». Игр: 2905.
#
#     Игра подходит для лиц **от 13 лет**. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики.
#
#
# - **M**: «Mature» — «Для взрослых». Игр: 1536.
#
#     Материалы игры **не подходят для лиц младше 17 лет**. Проекты с данным рейтингом могут содержать достаточно жёстокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории.
#
#
# - **AO**: «Adults Only 18+» — «Только для взрослых». Игр: 1.
#
#     **Нужно отметить**, что это игра Grand Theft Auto: San Andreas	для X-Box, релиз 2005 года. Та же игра имеет менее кровожадный рейтинг (М) для PS2 (релиз 2004), PC (релиз 2005) и X-Box 360 (релиз 2008).
#
#     Содержание игры только для взрослых **старше 18 лет**. Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое, а также сцены с обнажением. Большинство таких игр предназначено для персональных компьютеров. </details>
#
# ---
#
# Для сравнения брались два типа данных: без пропусков в рейтинге и с пропусками, заменёнными на рейтинг `unknown`.
#
# **Первые данные:**
#
# Количество игр с рейтингом E - 153
# Количество игр с рейтингом M - 149
# Количество игр с рейтингом T - 192
# Количество игр с рейтингом E10+ - 101
#
#
# **Вторые данные:**
# Здесь добавились игры с рейтингом unknown - 513
# Остальной набор тот же.
#
# По данным, которые очищены от пустот в рейтинге (595 строк за выбранный период), во всех странах, кроме Японии, ярко выражен рейтинг М. В Японии преобладает рейтинг Т (около 8 млн).
#
#
# Если же взять за основу данные, не очищенные от пустот в рейтинге (1108 строк), то преобладание рейтинга М остаётся по регионам, но в Японии `unknown` занимает тут же более 30 млн копий, что почти в 4 раза больше рейтинга T.
#
#
# Можно сказать, что в Японии игровая индустрия развивается отлично от остального мира, в том числе и офлайн. Кроме того, сама индустрия заточена не только под продажи по всему миру супер-хитов типа, но каких-то игр для своего региона. Также, как мы помним, в Японии шутеры на третьем месте, а именно они чаще всего имеют категорию М. Что же касается ролевых игр и приключений, то вполне нормально для них в том числе и рейтинг Т. С другой стороны, например, игра Fable III имеет рейтинг ESRB - T, а рейтинг CERO - Z, то есть, 18+. CERO - японский рейтинг. По сути аналог T для Японии это их местный С (от 15 лет) и, возможно, часть B (от 12 лет).
#
#
# Стоит отметить также тот факт, что у нас слишком много пропусков данных. Для всех регионов, кроме Японии, почти столько же, сколько занимает топовый рейтинг. И только в Японии почти 50%. Это говорит о том, что ни рынок Японии, ни их статистика не изучены.

# %% [markdown]
# # Проверка [гипотез](#hyp)
#
# I. [Средние пользовательские рейтинги платформ Xbox One и PC одинаковые](#h1).
#
# За нулевую гипотезу (H0) берём, что они одинаковы. Поскольку именно это утверждение нужно проверить.
#
# За альтернативную (H1) - не одинаковы. Потому как идём от противного.
#
# 1. За 2015-2016 годы гипотеза не может быть отвергнута: p-значение: 0.278, а средние выборок равны: 6.54 и 6.3 соответственно.
#
# 2. За весь период гипотезу отвергаем, поскольку p-значение: 1.3039339221792068e-05. Средние выборок равны: 6.52 и 7.07. Всё же разница ощутимее.
#
#
# II. [Средние пользовательские рейтинги жанров Action и Sports разные](#h2).
#
# Средние пользовательские рейтинги жанров Action и Sports разные. Для **Н0 берём гипотезу о том, что данные одинаковы**, а Н1 - разные.
#
# 1. За 2015-2016 годы гипотеза Н0 отвергнута, при этом p-значение: 1.0012846807938657e-13, а средние выборок 6.81 и 5.2.
#
# 2. За все года гипотезу Н0 отвергнуть не удалось, p-значение: 0.06480928064420527, а средние всего-то с разницей в единицу: 7.06 и 6.95 (Экшн и Спортс).
#
#
# Для проверки брался двувыборочный критерий Стьюдента (t-test), поскольку я сравнивал в обоих случаях **две независимые** выборки.

# %% [markdown]
# # Итоговые выводы
# <a id='final_resume'></a>

# %% [markdown]
# Перед аналитиком стояли две задачи:
#
# 1. Выявить определяющие успешность игры закономерности.
#
# 2. Спрогнозировать потенциальную популярность продуктов для планирования рекламных кампаний.
#
# ---
#
# Поскольку наш магазин продаёт игры по всему миру, то нам стоит обратить внимание на три топовые приставки: **PS4, XOne, 3DS** и **ПК**.
#
#
# 1. **Успешность игры** зависит от региона, жанра, возрастных ограничений и платформы. Всё это достаточно связано. При этом для части аудитории имеет значение оценка критиков. Ещё некоторая доля больше смотрит на оценки игроков. Связь достаточно низкая, но всё же есть.
#
# 2. **Рекламные кампании**/
#
# - Для **NA** потенциально популярны игры для приставок **PS4, XOne, 3DS**. Жанры: Shooter, Action и Sports. Причём упор сделать именно на шутеры и экшн. Также в РК игр для **PS4** и **XOne** стоит ненавязчиво отметить мнения критиков. Поскольку анонсирован выход новой версии **3DS** в 2017 году, рекомендуется рассмотреть вариант развития и этого направления.
#
#     **Возрастные ниши**. Основной упор сделать на "М". Остальные примерно поровну. В "М" основная категория - шутеры и экшн-игры.
#
#
# - Для **EU** игры для **PS4, XOne, PC** в тех же жанрах, что в регионе Северной Америки - Shooter, Action и Sports. Что касается мнений критиков, то их тоже стоит ненавязчиво подать. Касается и любителей игр на ПК.
#
#     **Возрастные ниши**. Здесь основная масса это "М". На втором месте стоит рейтинг "Е", а потому здесь стоит сделать упор именно на них, то есть нельзя исключать, что крайне небольшой сегмент игр в жанре гонок будет востребован. Равно, как и ролевые игры (4 место из 5). Достаточно сложно соотнести процент рейтинга "Е" с тройкой лидеров жанров. Здесь стоит более детально изучить рынок. Далее идут "Т" и "Е10+"
#
#
# - Для **JP** нужно продумать всё отдельно. Во-первых, это жанры: Action и Role-Playing. Причём в Японии явная тенденция к росту популярности ролевых игр, а потому требуется детально изучить рынок и спрос региона. Площакди: **3DS, PS4, PSV**.
#
#     **Возрастной рейтинг** для подростков - "Т", всех - "Е" и взрослых - "М".  Однако стоит учесть, что в полном датасете, где пропуски не вычищены, в Японии пустоты или `unknown`, как мы  назвали пропуски, занимает лидируещее место - почти половину всех продаж. Это тоже требует более детального изучения рынка, поскольку без этого **дать адекватный прогноз крайне сложно**.
#
#
# - **Остальные страны**. Потенциально сработают РК для игр в жанра Shooter, Action и Spotrs. Приставки **PS4, XOne**. Поддержка **PS3** уже прекращена и вряд ли стоит делать ставку на неё. Однако можно сделать ставку на **3DS**. Поскольку анонсирован выход новой версии **3DS** в 2017 году, рекомендуется рассмотреть вариант развития и этого направления.
#
#     **Возрастной рейтинг** в основном "М". За ним идут "Е" и "Т" с довольно ощутимой разницей.
#
# ---
#
# Хочу также отметить, что для более успешного успеха (:)) нужно провести исследование среди текущей аудитории. Так как мы продаём онлайн, у нас есть база почтовых адресов. По всем регионам. Нужно составить небольшой опросник на 10-15 вопросов. Разослать предложение пройти опрос, предложив за участие скидку в размере 5% на следующую покупку, например. То же сделать на сайте (кнопку) плюс тагретинг (заодно может привлечь немного новых клиентов). Тем, что согласится, выслать ссылку на опрос. После его заполнения и проверки на реальность, выдать бессрочный промик. Релевантную выборку делать на основе данных исследования вкупе с данными магазина о возрасте, предпочитаемых покупках и пр.
#
# ---
#
# # Крайне важно!
#
#
# **Помните, что исследованы далеко не все**. В данных много пропусков и нулевых значений в данных, о чём [говорилось](#describe) ранее.

# %% [markdown]
# <details>
#   <summary>Рабочая навигация. Тык</summary>
#
# [Наверх](#top)
#
# [Часть 1. Знакомство](#part1)
#
# [1 выводы](#1_resume)
#
# [Часть 2. Предобработка](#preprocessing)
#
# [2_выводы](#2_resume)
#
# [Часть 3. Исследовательский анализ](#ex_anal)
#
# [3.1 выводы](#vivod_1)
#
# [Данные 2015-2016 гг](#15_16)
#
# [3.2 выводы](#vivod_2)
#
# [Диаграммы размаха](#diagramma_top)
#
# [3.3 выводы](#vivod_3)
#
# [Влияние отзывов, корреляция](#corr)
#
# [3.4 выводы](#vivod_4)
#
# [Соотношение с другими платформами](#other_platforms)
#
# [3.5 выводы](#vivod_5)
#
# [3.6 выводы](#vivod_6)
#
# [Общее распределение по жанрам](#genres)
#
# [Выводы по жанрам](#genres_resume)
#
# [Часть 4. Портрет пользователя](#portrait)
#
# [ТОП 5 платформ по регионам](#top_5_plat)
#
# [Вывод по ТОП 5 платформ](#top_5_plat_reg)
#
# [ТОП 5 жанров по регионам](#top_5_genre)
#
# [Вывод по ТОП 5 жанров](#genres_top)
#
# [Влияние ESRB по регионам](#esrb)
#
# [Вывод по влиянию ESRB](#top_esrb)
#
# [Часть 5. Проверка гипотез](#hyp)
#
# [Первая гипотеза](#h1)
#
# [Вторая гипотеза](#h2)
#
# [Странные выводы по гипотезам](#h0h1resume)
#
# [Часть 6. Итог исследования](#resume)
#
# [Общий вывод](#final_resume)
#     </details>

# %% [raw]
# `<details>
#   <summary>Имя спойлера</summary>
#    Спрятанный текст
# </details>`
#
# <a id='intro'></a>
#
# <div class="alert alert-info">тут текст</div>
